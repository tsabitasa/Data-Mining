# %% [markdown]
# # ***Capstone Project 02 (Final Project) - Group H***
# # ***SENTIMEN PUBLIK TERHADAP NATURALISASI Pemain Timnas di Indonesia***
#
# | NIM | Nama | Deskripsi |
# | -------- | -------- | -------- |
# |11210940000073   | Tonny Pramudya Bagus Santoso | Mencari StopWords, Presentasi|
# |11220940000020  | Muhammad Abdul Ghofur |Scrapping, Mencari StopWords, Normalisasi Data Teks, Labelling, Visualisasi, Interpretassi|
# |11220940000047   | Rajwaa Warda Yunenda Putri      |Mencari StopWords, Visualisasi, PPT, dan Interpretasi|
# |11220940000052   | Tsabita Salma    |Labelling Sentimen, PPT, dan Interpretasi|
# |11220940000075   | Raden Arinal Haque |Labelling Sentimen, Presentasi, Edit Video|

# %% [markdown]
# ## Latar Belakang

# %% [markdown]
# Pada bulan September, saat Timnas Indonesia mulai berlaga di babak ketiga kualifikasi Piala dunia 2026, isu naturalisasi pemain menjadi perbincangan hangat. Kebijakan ini bertujuan meningkatkan performa tim keturunan sebagai Warga Negara Indonesia (WNI).
#
#
# Meskipun dianggap strategis untuk meningkatkan kualitas permainan, naturalisasi memicu pro dan kontra. Sebagian mendukungnya sebagai upaya mendongkrak prestasi, sementara yang lain mengkritik karena dianggap mengabaikan pembinaan pemain lokal.
#
#
# Diskusi ini ramai di Twitter (X), mencerminkan opini publik yang beragam. Analisis sentimen terhadap percakapan ini dapat memberikan wawasan penting bagi pemangku kebijakan untuk menyusun strategi sepak bola nasional yang lebih baik.

# %% [markdown]
# ## Rumusan Masalah

# %% [markdown]
# **Permasalahan**
# 1. Apa isu-isu utama yang terkait dengan Naturalisasi Pemain Timnas Indonesia?
# 2. Bagaimana sentimen publik terhadap Naturalisasi Pemain Timnas Indonesia?
# 3. Bagaimana  pola percakapan tentang hal ini di media sosial?
# 4. Bagaimana respons netizen terhadap Naturalisasi Pemain Timnas Indonesia?

# %% [markdown]
# **Periode Pengumpulan Data**
#
# 1-30 September 2024

# %% [markdown]
# **Sumber Data**
#
# Twitter (X)

# %% [markdown]
# **Kata Kunci**
# * naturalisasi bola indonesia
# * naturalisasi timnas indonesia
# * pemain keturunan indonesia

# %% [markdown]
# ## Packages

# %%
# !pip install Sastrawi
# !pip install unidecode
# !pip install textblob
# !python -m textblob.download_corpora
# !pip install wordcloud matplotlib
# !pip install squarify
# Out:
# Requirement already satisfied: Sastrawi in /usr/local/lib/python3.10/dist-packages (1.0.1)
# Requirement already satisfied: unidecode in /usr/local/lib/python3.10/dist-packages (1.3.8)
# Requirement already satisfied: textblob in /usr/local/lib/python3.10/dist-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.10/dist-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (4.67.1)
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package conll2000 to /root/nltk_data...
# [nltk_data]   Package conll2000 is already up-to-date!
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!
# Finished.
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.10/dist-packages (1.9.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.8.0)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from wordcloud) (11.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: squarify in /usr/local/lib/python3.10/dist-packages (0.4.4)

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from html import unescape
import pandas as pd
from unidecode import unidecode # Import the unidecode function
from textblob import TextBlob # Import the TextBlob class
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
import requests
import json
nltk.download('stopwords')
from nltk.corpus import stopwords
from textblob import TextBlob
import ast
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.lines import Line2D
from wordcloud import WordCloud
import re, operator, numpy as np
from tqdm import tqdm
from collections import Counter
import squarify
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Mempersiapkan Data

# %% [markdown]
# ## Scrapping Data Twitter (X)

# %% [markdown]
# Pada Proses Scrapping data dari twitter kami menggunakan library tweet-harvest dari Helmi Satria pada sumber link berikut:
# - https://helmisatria.com/blog/crawl-data-twitter-menggunakan-tweet-harvest/
# - https://colab.research.google.com/drive/1jQhAGKanGZ290rIaf06705xmhAB3vpD9
# - https://www.youtube.com/watch?v=OK6b5vvjRzY

# %% [markdown]
# ```
# # auth token yang dimiliki tiap pengguna twitter untuk akses
# twitter_auth_token = "...." # masukkan auth token twitter di sini
#
# # Import required Python package
# !pip install pandas
#
# # Install Node.js (because tweet-harvest built using Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg
#
# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list
#
# !sudo apt-get update
# !sudo apt-get install nodejs -y
#
# !node -v
#
#
# ## Limit 1000 tweet
# limit = 1000
# ## berikut list keyword kami
# listkey = ['naturalisasi bola indonesia',
#             'naturalisasi timnas indonesia',
#             'pemain keturunan indonesia']
# ```

# %% [markdown]
# Kami menggunakan 3 keyword dan melakukan beberapa kali scrapping pada tiap keyword, yakni di setiap 10 hari pada bulan september untuk memastikan semua tweet dalam bulan tersebut dapat diambil. Dengan demikian terdapat setidaknya terdapat 9 pengambilan
#
#
#
# ```
# # Contoh pengambilan yang kami lakukan
# ## Pengambilan Keyword Pertama di 10 hari pertama bulan September
# filename1 = 'naturalisasi_bola_indonesia_1.csv'
# search_keyword1 = 'naturalisasi bola indonesia until:2024-09-11 since:2024-09-01'
#
# !npx --yes tweet-harvest@2.6.1 -o "{filename1}" -s "{search_keyword1}" --tab "LATEST" -l {limit} --token {twitter_auth_token}
# ```

# %% [markdown]
# Lalu kami lakukan proses penggabungan dataframe dan Ekspor ke Github
#
#
# ```
# import pandas as pd
# import glob
#
# # Mencari semua file CSV di dalam folder 'tweets-data'
# csv_files = glob.glob('tweets-data/*.csv') # list nama file yang disimpan
# csv_files.sort()  # Use the sort() method of the list object
#
# n = 0
# for filename in csv_files: ## Menggabungkan file csv dalam bentuk dataframe
#   # Read the CSV file into a pandas DataFrame
#   if n == 0:
#     df = pd.read_csv(filename, delimiter=",")
#     n = 1
#   else:
#     df2 = pd.read_csv(filename, delimiter=",")
#     df = pd.concat([df, df2])
#     n+=1
#
# # Membuang duplikat berdasarkan id_str
# df.drop_duplicates(subset=['id_str'], keep='first', inplace=True)
# df.reset_index(drop=True, inplace=True)
#
# # Ekspor Data Hasil Scrapping
# from google.colab import files
# namafile = "DATAX_Naturalisasi_fix.csv"
# df.to_csv(namafile, index=False)
# files.download(namafile)
# "Exported"
# ```

# %% [markdown]
# ## Import Data Hasil Scrapping

# %% [markdown]
# Sebelumnya pada link berikut
# - https://docs.google.com/spreadsheets/d/1W2n8ny7i5A74D0c-iB-gQUG_eeaZmHEAQgixtVVokmg/edit?usp=sharing
#
# Kami telah melakukan proses pelabelan sentimen (3:Positif, 1:Negatif, dan 2:Netral) pada setiap tweet sebelum data ini diunggah ke GitHub dan diimpor ke sini. Langkah ini dilakukan untuk mendukung analisis sentimen publik terkait topik naturalisasi Timnas Indonesia.

# %%
# Import data hasil scrapping twitter (X)
import pandas as pd

file_ = 'data/Data_X_Naturalisasi_Timnas_Indonesia_Sep.csv'
try: #Loading Locally
    df = pd.read_csv(file_)
except Exception as err_:
    print(err_," Trying to load data from GitHub.")
    # !mkdir data
    # !wget -P data/ https://raw.githubusercontent.com/mabdulghofur142/Data-Mining/refs/heads/main/Final%20Project/Data_X_Naturalisasi_Timnas_Indonesia_Sep.csv
    df = pd.read_csv(file_)

print(df.shape)
df.sample(10)
# Out:
# (2537, 16)
#       conversation_id_str                      created_at  favorite_count  \
# 1790  1837357836961206600  Sat Sep 21 05:06:59 +0000 2024               0
# 746   1836939695311532250  Fri Sep 20 01:25:26 +0000 2024               0
# 1593  1839970416909222234  Sat Sep 28 10:08:27 +0000 2024              62
# 1686  1839115082233688109  Thu Sep 26 01:29:39 +0000 2024               3
# 1727  1838206699733442692  Mon Sep 23 13:20:04 +0000 2024               0
# 795   1836711693205770403  Thu Sep 19 10:19:26 +0000 2024               0
# 2080  1835742155169829124  Mon Sep 16 18:06:52 +0000 2024               0
# 2352  1834121164261916741  Thu Sep 12 06:45:36 +0000 2024               0
# 824   1836683926120861773  Thu Sep 19 08:29:06 +0000 2024               0
# 2409  1840421659066671147  Mon Sep 30 08:55:33 +0000 2024               0
#
#                                               full_text               id_str  \
# 1790  Beri Naturalisasi Kemenkumham Dukung Jalan Tim...  1837357836961206600
# 746   Beri Naturalisasi Kemenkumham Dukung Jalan Tim...  1836939695311532250
# 1593  Begini Komentar Komandan Korea Bambang Pacul T...  1839970416909222234
# 1686  Timnas U-20 Indonesia baru saja menuai hasil p...  1839115082233688109
# 1727  Proyek naturalisasi tidak hanya dilakukan Timn...  1838206699733442692
# 795   Beri Naturalisasi Kemenkumham Dukung Jalan Tim...  1836711693205770403
# 2080  Ketika para pemain keturunan dijadikan WNI ter...  1835742161322836145
# 2352  Hah apaan anjerr Ada aja gebrakan nya heran ba...  1834121164261916741
# 824   Beri Naturalisasi Kemenkumham Dukung Jalan Tim...  1836683926120861773
# 2409  @unmagnetism Senior Ama Juniornya sama aja sam...  1840676849535631613
#
#                                               image_url  \
# 1790    https://pbs.twimg.com/media/GX-ZTfRaUAIgvMd.jpg
# 746     https://pbs.twimg.com/media/GX4e5kYaUAEuLhi.jpg
# 1593  https://pbs.twimg.com/ext_tw_video_thumb/18399...
# 1686    https://pbs.twimg.com/media/GYXZNcpXsAAPa2s.png
# 1727                                                NaN
# 795     https://pbs.twimg.com/media/GX1Ph3oacAArlOo.jpg
# 2080                                                NaN
# 2352                                                NaN
# 824                                                 NaN
# 2409                                                NaN
#
#      in_reply_to_screen_name lang                      location  quote_count  \
# 1790                     NaN   in  Kota Tasikmalaya, Jawa Barat            0
# 746                      NaN   in  Tabalong, Kalimantan Selatan           10
# 1593                     NaN   in                           NaN            3
# 1686                     NaN   in                   Stadion GBK            0
# 1727                     NaN   in                     Surabaya             0
# 795                      NaN   in   Jl. Kaliurang KM. 17 Sleman            0
# 2080             aa_zulfikar   in                Padang Mahsyar            0
# 2352                     NaN   in                           NaN            0
# 824                      NaN   in                           NaN            0
# 2409             unmagnetism   in                           NaN            0
#
#       reply_count  retweet_count  \
# 1790            1              0
# 746             0              0
# 1593            2             26
# 1686            6              0
# 1727            1              0
# 795             1              0
# 2080            1              0
# 2352            1              0
# 824             0              0
# 2409            0              0
#
#                                               tweet_url          user_id_str  \
# 1790  https://x.com/lapas2btasik/status/183735783696...  1589549889515450368
# 746   https://x.com/lapas2btanjung/status/1836939695...  1420951960950173701
# 1593  https://x.com/DS_yantie/status/183997041690922...  1374686160748830724
# 1686  https://x.com/InfosuporterID/status/1839115082...           4379131152
# 1727  https://x.com/aksaradotid/status/1838206699733...  1734728962172133376
# 795   https://x.com/lapsustik_yk/status/183671169320...  1222678271009021952
# 2080  https://x.com/aa_zulfikar/status/1835742161322...  1081191562220982272
# 2352  https://x.com/CharityWld/status/18341211642619...  1341772121471533056
# 824   https://x.com/AktualonlineM/status/18366839261...  1472952488873455616
# 2409  https://x.com/ilhamlomo90/status/1840676849535...  1281823214088286208
#
#             username  sentiment
# 1790    lapas2btasik          2
# 746   lapas2btanjung          2
# 1593       DS_yantie          2
# 1686  InfosuporterID          2
# 1727     aksaradotid          2
# 795     lapsustik_yk          2
# 2080     aa_zulfikar          2
# 2352      CharityWld          3
# 824    AktualonlineM          2
# 2409     ilhamlomo90          1

# %%
# Jumlah Tweet
print("Jumlah Tweet yang kami peroleh:", df.shape[0]," Tweet")
# Out:
# Jumlah Tweet yang kami peroleh: 2537  Tweet

# %%
df.columns
# Out:
# Index(['conversation_id_str', 'created_at', 'favorite_count', 'full_text',
#        'id_str', 'image_url', 'in_reply_to_screen_name', 'lang', 'location',
#        'quote_count', 'reply_count', 'retweet_count', 'tweet_url',
#        'user_id_str', 'username', 'sentiment'],
#       dtype='object')

# %% [markdown]
# ## Normalisasi data teks

# %%
# Menghapus kolom yang tidak digunakan
df.drop(columns=['id_str','image_url','in_reply_to_screen_name','lang','conversation_id_str'],inplace=True)

# %% [markdown]
# ### Menghilangkan hal yang tidak diperlukan di dalam teks

# %%
# Fungsi yang digunakan
import re
def get_hashtag(df,teks): # untuk mendapatkan hashtag
    hashtag = [username[1:] for username in re.findall(r'#\w+',teks)]
    return hashtag
def get_username(df,teks): # untuk mendapatkan list user yang mention atau reply
    usernames = [username[1:] for username in re.findall(r'@\w+',teks)]
    return usernames

def get_teks(df,teks): # bersihkan teks dari mention dan hashtag
    teks = re.sub(r'@\w+','',teks).strip()
    teks = re.sub(r'#\w+','',teks).strip()
    return teks

def remove_links_email(teks): # besihkan teks dari link dan email
    docx = teks.strip()
    urlPattern = re.compile(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    emailPattern = re.compile(r'[\w._%+-]+@[\w\.-]+\.[a-zA-Z]{2,4}')
    docx = re.sub(urlPattern,' ', docx) # Remove links
    docx = re.sub(emailPattern,' ', docx) # Remove email
    return docx

def unidecode_text(text): # fungsi untuk encode format ASCII dan membersihkan posting media sosial/website dengan entitas html menggunakan fungsi "unescape" di modul "html"
    return unescape(unidecode(text))


df['username_in_teks'] = df['full_text'].apply(lambda x: get_username(df,x))
df['hastag_in_teks'] = df['full_text'].apply(lambda x: get_hashtag(df,x))
df['teks_new'] = df['full_text'].apply(lambda x: get_teks(df,x))
df['teks_new'] = df['teks_new'].apply(lambda x: remove_links_email(x))
df['teks_new'] = df['teks_new'].apply(lambda x: unidecode_text(x))
df.head()
# Out:
#                        created_at  favorite_count  \
# 0  Tue Sep 10 23:27:19 +0000 2024               0
# 1  Tue Sep 10 23:12:05 +0000 2024               0
# 2  Tue Sep 10 22:03:04 +0000 2024              39
# 3  Tue Sep 10 21:02:54 +0000 2024               0
# 4  Tue Sep 10 20:36:13 +0000 2024               0
#
#                                            full_text   location  quote_count  \
# 0  @aldibawazier_ setuju naturalisasi jangan hany...        NaN            0
# 1  Performa 10 Pemain Naturalisasi saat Timnas In...  Indonesia            0
# 2  Ini Dia Cara Indonesia BIKIN FRUSTRASI Austral...  Indonesia            1
# 3  Dear @PSSI Tanpa Naturalisasi 🇮🇩 tidak akan sa...        NaN            0
# 4  @Box2boxID @Box2BoxBola Bangga sama pemain nat...        NaN            0
#
#    reply_count  retweet_count  \
# 0            0              0
# 1            0              0
# 2            6              9
# 3            1              0
# 4            0              0
#
#                                            tweet_url          user_id_str  \
# 0  https://x.com/AkunanSaya/status/18336484794005...  1425023300023984134
# 1  https://x.com/bolacomID/status/183364464622194...           1486284086
# 2  https://x.com/Box2BoxBola/status/1833627276950...           1956656786
# 3  https://x.com/mekanasirah/status/1833612133290...  1655265184238403585
# 4  https://x.com/jayusman92/status/18336054204534...  1257887251616301060
#
#       username  sentiment          username_in_teks hastag_in_teks  \
# 0   AkunanSaya          3           [aldibawazier_]             []
# 1    bolacomID          3                        []             []
# 2  Box2BoxBola          2                        []            [8]
# 3  mekanasirah          1                    [PSSI]             []
# 4   jayusman92          1  [Box2boxID, Box2BoxBola]             []
#
#                                             teks_new
# 0  setuju naturalisasi jangan hanya pemain sepak ...
# 1  Performa 10 Pemain Naturalisasi saat Timnas In...
# 2  Ini Dia Cara Indonesia BIKIN FRUSTRASI Austral...
# 3  Dear  Tanpa Naturalisasi  tidak akan sampai di...
# 4  Bangga sama pemain naturalisasi? Tutup saja li...

# %% [markdown]
# ### Penanganan Slang/Singkatan

# %% [markdown]
# Pada Link berikut:
# - https://colab.research.google.com/drive/1hCJ8mrCtubMbimKWU1LLRPxoPdXtV9Gh?usp=sharing
#
# Kami gabungkan slang singkatan yang dikumpulkan oleh kami dengan yang ada pada link github berikut:
# - https://raw.githubusercontent.com/taudataanalytics/eLearning/refs/heads/master/data/slang.txt
#
# lalu di upload kembali ke dalam Github untuk kami gunakan

# %%
# mengimport kumpulan slang/singkatan dari internet dan yang sudah kami buat
# URL of the raw JSON file from GitHub
url = 'https://raw.githubusercontent.com/mabdulghofur142/Data-Mining/main/Final%20Project/slangS_Final_Project_Group_H.json'

# Fetch the JSON data from GitHub
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Load the content into a Python dictionary
    slangS = response.json()
    print("Dictionary loaded successfully:")
    # print(slangS)
    print(len(slangS))
else:
    print("Failed to fetch the file, status code:", response.status_code)

slangS.pop('et')
slangS.pop('is')
slangS.pop('rg')
slangS.pop('sty')
slangS.pop('as')
slangS.pop('euforia')
slangS.pop('Euforia')

slang_nama = {'STY':'shin tae-yong',
              'PG':'peter gontha',
              'RG':'rocky gerung',
              'RK':'Ridwan Kamil',
              'IS':'indra sjafri',
              'ET':'erick thohir',
              'AS':'Amerika Serikat',
              }
# Out:
# Dictionary loaded successfully:
# 3007

# %%
# Melakukan penanganan slang/singkatan
def replace_slang(text,dict_slang):
    # Mengganti frasa menggunakan regex
    for slang, pengganti in dict_slang.items():
        text = re.sub(r'\b' + re.escape(slang) + r'\b', pengganti, text) # versi tanpa ignorecase, sensitif dengan huruf kapital atau kecil
    return text

# dikarenakan ada beberapa perbedaan format penulisan dalam dictionary slang kami maka dilakukan beberapa proses,
df['teks_slang1'] = df['teks_new'].apply(lambda x: replace_slang(x, slang_nama)) # replace singkatan nama yang sensitive case
df['teks_slang2'] = df['teks_slang1'].apply(lambda x: replace_slang(x, slangS)) # replace singkatan yang sensitive case
df['teks_slang3'] = df['teks_slang2'].apply(lambda x: replace_slang(x.lower(), slangS)) # replace singkatan dengan lower

# %%
# Fungsi untuk menghapus angka di akhir kata
def remove_trailing_numbers(text):
    return re.sub(r'\d+\b', '', text)

df['teks_slang3'] = df['teks_slang3'].apply(lambda x: remove_trailing_numbers(x))

# %%
# jumlah singkatan STY sebelum penanganan slang/singkatan
print('Singkatan STY sebelum: ',df['teks_new'].str.contains('STY').sum())
print('Singkatan lvl sebelum: ',df['teks_new'].str.contains('lvl').sum())
# Out:
# Singkatan STY sebelum:  39
# Singkatan lvl sebelum:  2

# %%
# jumlah singkatan STY dan lvl setelah penanganan slang/singkatan
print('Singkatan STY setelah: ',df['teks_slang3'].str.contains('STY').sum())
print('Singkatan lvl setelah: ',df['teks_slang3'].str.contains('lvl').sum())
# Out:
# Singkatan STY setelah:  0
# Singkatan lvl setelah:  0

# %%
# fungsi bersihkan simbol tak perlu
def remove_symbol(teks):
    docx = teks.strip()
    docx = re.sub(r'[^\w]', ' ', docx) # Remove Symbol, keep "_" ... recommended
    return docx

df['teks_rapih'] = df['teks_slang3'].apply(lambda x: remove_symbol(x))

# %% [markdown]
# ### Penanganan Stopword

# %%
# Load stopword sastrawi
factory = StopWordRemoverFactory() # Create an instance of the StopWordRemoverFactory
Sastrawi_StopWords_id = factory.get_stop_words()

# print(Sastrawi_StopWords_id)
print(len(Sastrawi_StopWords_id))

Sastrawi_StopWords_id = set(Sastrawi_StopWords_id)
# Out:
# 126

# %%
# Load stopword dari nltk
# Mengambil stopwords dalam bahasa Inggris
stop_words = set(stopwords.words('english'))

# Mengambil stopwords dalam bahasa Indonesia
stop_words_id = set(stopwords.words('indonesian'))


# print("Stopwords Bahasa Inggris:", stop_words)
# print("Stopwords Bahasa Indonesia:", stop_words_id)
print(len(stop_words))
print(len(stop_words_id))
# Out:
# 179
# 757

# %%
stopwords = Sastrawi_StopWords_id | stop_words | stop_words_id # gabung semua stopwords
len(stopwords)
# Out:
# 953

# %%
# fungsi bersihkan stopwords
def clean_text(text, stopwords):
    # Mengubah teks menjadi huruf kecil
    text = text.lower()

    # Tokenisasi menggunakan TextBlob
    tokens = TextBlob(text).words

    # Menghapus stopwords
    filtered_tokens = [token for token in tokens if token not in stopwords]

    # Menggabungkan kembali token menjadi teks
    return ' '.join(filtered_tokens)

# %%
df['clean_teks'] = df['teks_rapih'].apply(lambda x: clean_text(x, stopwords))
df.head()
# Out:
#                        created_at  favorite_count  \
# 0  Tue Sep 10 23:27:19 +0000 2024               0
# 1  Tue Sep 10 23:12:05 +0000 2024               0
# 2  Tue Sep 10 22:03:04 +0000 2024              39
# 3  Tue Sep 10 21:02:54 +0000 2024               0
# 4  Tue Sep 10 20:36:13 +0000 2024               0
#
#                                            full_text   location  quote_count  \
# 0  @aldibawazier_ setuju naturalisasi jangan hany...        NaN            0
# 1  Performa 10 Pemain Naturalisasi saat Timnas In...  Indonesia            0
# 2  Ini Dia Cara Indonesia BIKIN FRUSTRASI Austral...  Indonesia            1
# 3  Dear @PSSI Tanpa Naturalisasi 🇮🇩 tidak akan sa...        NaN            0
# 4  @Box2boxID @Box2BoxBola Bangga sama pemain nat...        NaN            0
#
#    reply_count  retweet_count  \
# 0            0              0
# 1            0              0
# 2            6              9
# 3            1              0
# 4            0              0
#
#                                            tweet_url          user_id_str  \
# 0  https://x.com/AkunanSaya/status/18336484794005...  1425023300023984134
# 1  https://x.com/bolacomID/status/183364464622194...           1486284086
# 2  https://x.com/Box2BoxBola/status/1833627276950...           1956656786
# 3  https://x.com/mekanasirah/status/1833612133290...  1655265184238403585
# 4  https://x.com/jayusman92/status/18336054204534...  1257887251616301060
#
#       username  sentiment          username_in_teks hastag_in_teks  \
# 0   AkunanSaya          3           [aldibawazier_]             []
# 1    bolacomID          3                        []             []
# 2  Box2BoxBola          2                        []            [8]
# 3  mekanasirah          1                    [PSSI]             []
# 4   jayusman92          1  [Box2boxID, Box2BoxBola]             []
#
#                                             teks_new  \
# 0  setuju naturalisasi jangan hanya pemain sepak ...
# 1  Performa 10 Pemain Naturalisasi saat Timnas In...
# 2  Ini Dia Cara Indonesia BIKIN FRUSTRASI Austral...
# 3  Dear  Tanpa Naturalisasi  tidak akan sampai di...
# 4  Bangga sama pemain naturalisasi? Tutup saja li...
#
#                                          teks_slang1  \
# 0  setuju naturalisasi jangan hanya pemain sepak ...
# 1  Performa 10 Pemain Naturalisasi saat Timnas In...
# 2  Ini Dia Cara Indonesia BIKIN FRUSTRASI Austral...
# 3  Dear  Tanpa Naturalisasi  tidak akan sampai di...
# 4  Bangga sama pemain naturalisasi? Tutup saja li...
#
#                                          teks_slang2  \
# 0  setuju naturalisasi jangan hanya pemain sepak ...
# 1  Performa 10 Pemain Naturalisasi saat Timnas In...
# 2  Ini Dia Cara Indonesia BIKIN FRUSTRASI Austral...
# 3  Dear  Tanpa Naturalisasi  tidak akan sampai di...
# 4  Bangga sama pemain naturalisasi? Tutup saja li...
#
#                                          teks_slang3  \
# 0  setuju naturalisasi jangan hanya pemain sepak ...
# 1  performa  pemain naturalisasi saat timnas indo...
# 2  ini dia cara indonesia membuat frustrasi austr...
# 3  dear  tanpa naturalisasi  tidak akan sampai di...
# 4  bangga sama pemain naturalisasi? tutup saja li...
#
#                                           teks_rapih  \
# 0  setuju naturalisasi jangan hanya pemain sepak ...
# 1  performa  pemain naturalisasi saat timnas indo...
# 2  ini dia cara indonesia membuat frustrasi austr...
# 3  dear  tanpa naturalisasi  tidak akan sampai di...
# 4  bangga sama pemain naturalisasi  tutup saja li...
#
#                                           clean_teks
# 0  setuju naturalisasi pemain sepak bola presiden...
# 1  performa pemain naturalisasi timnas indonesia ...
# 2  indonesia frustrasi australia box2box sepak bo...
# 3  dear naturalisasi ronde naturalisasi bukti bob...
# 4  bangga pemain naturalisasi tutup liga sepak bo...

# %% [markdown]
# ### Lematisasi

# %%
# Membuat stemmer Sastrawi untuk proses Lemmatisasi
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# fungsi untuk Lemmatisasi
def stem_text(text):
    # Melakukan Lemmatisasi  pada teks
    return stemmer.stem(text)

df['stem_teks'] = df['clean_teks'].apply(lambda x: stem_text(x))
df.head()
# Out:
#                        created_at  favorite_count  \
# 0  Tue Sep 10 23:27:19 +0000 2024               0
# 1  Tue Sep 10 23:12:05 +0000 2024               0
# 2  Tue Sep 10 22:03:04 +0000 2024              39
# 3  Tue Sep 10 21:02:54 +0000 2024               0
# 4  Tue Sep 10 20:36:13 +0000 2024               0
#
#                                            full_text   location  quote_count  \
# 0  @aldibawazier_ setuju naturalisasi jangan hany...        NaN            0
# 1  Performa 10 Pemain Naturalisasi saat Timnas In...  Indonesia            0
# 2  Ini Dia Cara Indonesia BIKIN FRUSTRASI Austral...  Indonesia            1
# 3  Dear @PSSI Tanpa Naturalisasi 🇮🇩 tidak akan sa...        NaN            0
# 4  @Box2boxID @Box2BoxBola Bangga sama pemain nat...        NaN            0
#
#    reply_count  retweet_count  \
# 0            0              0
# 1            0              0
# 2            6              9
# 3            1              0
# 4            0              0
#
#                                            tweet_url          user_id_str  \
# 0  https://x.com/AkunanSaya/status/18336484794005...  1425023300023984134
# 1  https://x.com/bolacomID/status/183364464622194...           1486284086
# 2  https://x.com/Box2BoxBola/status/1833627276950...           1956656786
# 3  https://x.com/mekanasirah/status/1833612133290...  1655265184238403585
# 4  https://x.com/jayusman92/status/18336054204534...  1257887251616301060
#
#       username  sentiment          username_in_teks hastag_in_teks  \
# 0   AkunanSaya          3           [aldibawazier_]             []
# 1    bolacomID          3                        []             []
# 2  Box2BoxBola          2                        []            [8]
# 3  mekanasirah          1                    [PSSI]             []
# 4   jayusman92          1  [Box2boxID, Box2BoxBola]             []
#
#                                             teks_new  \
# 0  setuju naturalisasi jangan hanya pemain sepak ...
# 1  Performa 10 Pemain Naturalisasi saat Timnas In...
# 2  Ini Dia Cara Indonesia BIKIN FRUSTRASI Austral...
# 3  Dear  Tanpa Naturalisasi  tidak akan sampai di...
# 4  Bangga sama pemain naturalisasi? Tutup saja li...
#
#                                          teks_slang1  \
# 0  setuju naturalisasi jangan hanya pemain sepak ...
# 1  Performa 10 Pemain Naturalisasi saat Timnas In...
# 2  Ini Dia Cara Indonesia BIKIN FRUSTRASI Austral...
# 3  Dear  Tanpa Naturalisasi  tidak akan sampai di...
# 4  Bangga sama pemain naturalisasi? Tutup saja li...
#
#                                          teks_slang2  \
# 0  setuju naturalisasi jangan hanya pemain sepak ...
# 1  Performa 10 Pemain Naturalisasi saat Timnas In...
# 2  Ini Dia Cara Indonesia BIKIN FRUSTRASI Austral...
# 3  Dear  Tanpa Naturalisasi  tidak akan sampai di...
# 4  Bangga sama pemain naturalisasi? Tutup saja li...
#
#                                          teks_slang3  \
# 0  setuju naturalisasi jangan hanya pemain sepak ...
# 1  performa  pemain naturalisasi saat timnas indo...
# 2  ini dia cara indonesia membuat frustrasi austr...
# 3  dear  tanpa naturalisasi  tidak akan sampai di...
# 4  bangga sama pemain naturalisasi? tutup saja li...
#
#                                           teks_rapih  \
# 0  setuju naturalisasi jangan hanya pemain sepak ...
# 1  performa  pemain naturalisasi saat timnas indo...
# 2  ini dia cara indonesia membuat frustrasi austr...
# 3  dear  tanpa naturalisasi  tidak akan sampai di...
# 4  bangga sama pemain naturalisasi  tutup saja li...
#
#                                           clean_teks  \
# 0  setuju naturalisasi pemain sepak bola presiden...
# 1  performa pemain naturalisasi timnas indonesia ...
# 2  indonesia frustrasi australia box2box sepak bo...
# 3  dear naturalisasi ronde naturalisasi bukti bob...
# 4  bangga pemain naturalisasi tutup liga sepak bo...
#
#                                            stem_teks
# 0  tuju naturalisasi main sepak bola presiden wak...
# 1  performa main naturalisasi timnas indonesia im...
# 2  indonesia frustrasi australia box2box sepak bo...
# 3  dear naturalisasi ronde naturalisasi bukti bob...
# 4  bangga main naturalisasi tutup liga sepak bola...

# %% [markdown]
# ## Ekspor Data Clean

# %%
# Ekspor hasil data bersih
df.to_csv('data/data_final_all_fix.csv',index=False)

# %% [markdown]
# Data diekspor dan akan diunggah ke GitHub untuk memudahkan proses visualisasi, sehingga tidak perlu menjalankan ulang seluruh proses dari data mentah.

# %% [markdown]
# # Visualisasi dan Interpretasi

# %% [markdown]
# ## Import Data Clean

# %%
# Import data yang telah di ekspor
import pandas as pd

file_ = 'data/data_final_all_fix.csv'
try: #Loading Locally
    df_final = pd.read_csv(file_)
except Exception as err_:
    print(err_," Trying to load data from GitHub.")
    # !mkdir data
    # !wget -P data/ https://raw.githubusercontent.com/mabdulghofur142/Data-Mining/refs/heads/main/Final%20Project/data_final_all_fix.csv
    df_final = pd.read_csv(file_)

print(df_final.shape)
df_final.sample(10)
# Out:
# (2537, 20)
#                           created_at  favorite_count  \
# 492   Sun Sep 08 07:04:52 +0000 2024               0
# 1981  Thu Sep 05 09:40:09 +0000 2024               2
# 1243  Sat Sep 14 13:16:04 +0000 2024             114
# 572   Fri Sep 06 20:52:23 +0000 2024               0
# 2270  Fri Sep 13 02:54:04 +0000 2024               0
# 364   Sun Sep 29 14:42:27 +0000 2024              10
# 1664  Thu Sep 26 09:50:17 +0000 2024               0
# 2157  Sun Sep 15 02:31:10 +0000 2024               0
# 872   Thu Sep 19 05:45:34 +0000 2024               0
# 1891  Sun Sep 08 02:53:49 +0000 2024               0
#
#                                               full_text  \
# 492   Perbedaan Maroko dgn Indonesia hanya di status...
# 1981  Shin Tae-yong menyatakan masih ada beberapa pe...
# 1243  @msaid_didu @PeterGontha Kalo mau nyerang muly...
# 572   Setelah gantung sepatu Maarten paes dan pemain...
# 2270  @gilabola_ina Kalau mikirnya di balik gimana p...
# 364   @nimbrungmulu Tidak bisa dipungkuri kualitas d...
# 1664  Main di Liga Jerman Bintang Muda Naturalisasi ...
# 2157  @ibamhariri Baru kemarin misuh² masalah pemain...
# 872   PSSI Diminta Kurangi Naturalisasi Pemain untuk...
# 1891  @Mah5Utari Bukan mengharuskan merekrut pemain ...
#
#                    location  quote_count  reply_count  retweet_count  \
# 492                     NaN            0            0              0
# 1981              Indonesia            0            0              0
# 1243                    NaN            0           12              2
# 572                     NaN            0            0              0
# 2270    Indonesia - Jakarta            0            0              0
# 364   Yogyakarta, Indonesia            0            0              0
# 1664    Kota Serang, Banten            0            0              0
# 2157                    NaN            0            0              0
# 872               Indonesia            0            0              0
# 1891                Area 51            0            0              0
#
#                                               tweet_url          user_id_str  \
# 492   https://x.com/MTAryaa27/status/183267645957334...  1645810207107473408
# 1981  https://x.com/BolaSportcom/status/183162837730...             78239324
# 1243  https://x.com/caluxcreeck/status/1834944203320...  1134676273601474560
# 572   https://x.com/BUDI_PERMADI26/status/1832159936...            252944107
# 2270  https://x.com/Id_klasikretro/status/1834425285...           1521647856
# 364   https://x.com/theinson02/status/18404017628779...           1051937562
# 1664  https://x.com/BantenViva/status/18392410718361...  1717850323346399232
# 2157  https://x.com/IQBALPILIANG97/status/1835144297...  1645569495933792266
# 872   https://x.com/bisnisjuraganID/status/183664277...            943014002
# 1891  https://x.com/canikissuonce/status/18326132829...  1201810689880289280
#
#              username  sentiment               username_in_teks  \
# 492         MTAryaa27          1                             []
# 1981     BolaSportcom          2                             []
# 1243      caluxcreeck          3  ['msaid_didu', 'PeterGontha']
# 572    BUDI_PERMADI26          1                             []
# 2270   Id_klasikretro          3               ['gilabola_ina']
# 364        theinson02          3               ['nimbrungmulu']
# 1664       BantenViva          2                             []
# 2157   IQBALPILIANG97          2                 ['ibamhariri']
# 872   bisnisjuraganID          2                             []
# 1891    canikissuonce          3                  ['Mah5Utari']
#
#                                          hastag_in_teks  \
# 492                                                  []
# 1981                                      ['TimnasDay']
# 1243                                                 []
# 572                             ['Timnas', 'sepakbola']
# 2270                                                 []
# 364                                                  []
# 1664  ['TimnasIndonesia', 'TimnasIndonesiaMandiri', ...
# 2157                                                 []
# 872                                                  []
# 1891                                                 []
#
#                                                teks_new  \
# 492   Perbedaan Maroko dgn Indonesia hanya di status...
# 1981  Shin Tae-yong menyatakan masih ada beberapa pe...
# 1243  Kalo mau nyerang mulyono dkk serang aja dah ga...
# 572   Setelah gantung sepatu Maarten paes dan pemain...
# 2270  Kalau mikirnya di balik gimana pak peter? Bany...
# 364   Tidak bisa dipungkuri kualitas dan visi misi d...
# 1664  Main di Liga Jerman Bintang Muda Naturalisasi ...
# 2157  Baru kemarin misuh2 masalah pemain keturunan y...
# 872   PSSI Diminta Kurangi Naturalisasi Pemain untuk...
# 1891  Bukan mengharuskan merekrut pemain keturunan t...
#
#                                             teks_slang1  \
# 492   Perbedaan Maroko dgn Indonesia hanya di status...
# 1981  Shin Tae-yong menyatakan masih ada beberapa pe...
# 1243  Kalo mau nyerang mulyono dkk serang aja dah ga...
# 572   Setelah gantung sepatu Maarten paes dan pemain...
# 2270  Kalau mikirnya di balik gimana pak peter? Bany...
# 364   Tidak bisa dipungkuri kualitas dan visi misi d...
# 1664  Main di Liga Jerman Bintang Muda Naturalisasi ...
# 2157  Baru kemarin misuh2 masalah pemain keturunan y...
# 872   PSSI Diminta Kurangi Naturalisasi Pemain untuk...
# 1891  Bukan mengharuskan merekrut pemain keturunan t...
#
#                                             teks_slang2  \
# 492   Perbedaan Maroko dengan Indonesia hanya di sta...
# 1981  Shin Tae-yong menyatakan masih ada beberapa pe...
# 1243  Kalo ingin serang jokowi dan kawan-kawan seran...
# 572   Setelah pensiun Maarten paes dan pemain natura...
# 2270  Kalau mikirnya di balik bagaimana bapak peter?...
# 364   Tidak bisa dipungkuri kualitas dan visi misi d...
# 1664  Main di Liga Jerman Bintang Muda Naturalisasi ...
# 2157  Baru kemarin misuh2 masalah pemain keturunan y...
# 872   PSSI Diminta Kurangi Naturalisasi Pemain untuk...
# 1891  Bukan mengharuskan merekrut pemain keturunan t...
#
#                                             teks_slang3  \
# 492   perbedaan maroko dengan indonesia hanya di sta...
# 1981  shin tae-yong menyatakan masih ada beberapa pe...
# 1243  kalau ingin serang jokowi dan kawan-kawan sera...
# 572   setelah pensiun maarten paes dan pemain natura...
# 2270  kalau mikirnya di balik bagaimana bapak peter?...
# 364   tidak bisa dipungkuri kualitas dan visi misi d...
# 1664  bermain di liga jerman bintang muda naturalisa...
# 2157  baru kemarin misuh masalah pemain keturunan ya...
# 872   pssi diminta kurangi naturalisasi pemain untuk...
# 1891  bukan mengharuskan merekrut pemain keturunan t...
#
#                                              teks_rapih  \
# 492   perbedaan maroko dengan indonesia hanya di sta...
# 1981  shin tae yong menyatakan masih ada beberapa pe...
# 1243  kalau ingin serang jokowi dan kawan kawan sera...
# 572   setelah pensiun maarten paes dan pemain natura...
# 2270  kalau mikirnya di balik bagaimana bapak peter ...
# 364   tidak bisa dipungkuri kualitas dan visi misi d...
# 1664  bermain di liga jerman bintang muda naturalisa...
# 2157  baru kemarin misuh masalah pemain keturunan ya...
# 872   pssi diminta kurangi naturalisasi pemain untuk...
# 1891  bukan mengharuskan merekrut pemain keturunan t...
#
#                                              clean_teks  \
# 492   perbedaan maroko indonesia status kewarganegar...
# 1981  shin tae yong pemain keturunan memperkuat timn...
# 1243  serang jokowi kawan kawan serang mengurusi pem...
# 572   pensiun maarten paes pemain naturalisasi kerja...
# 2270  mikirnya peter pemain liga eropa belanda ketur...
# 364   dipungkuri kualitas visi misi pemain keturunan...
# 1664  bermain liga jerman bintang muda naturalisasi ...
# 2157  kemarin misuh pemain keturunan berdarah indone...
# 872   pssi kurangi naturalisasi pemain timnas indone...
# 1891  mengharuskan merekrut pemain keturunan merekru...
#
#                                               stem_teks
# 492   beda maroko indonesia status kewarganegaraan g...
# 1981  shin tae yong main turun kuat timnas indonesia...
# 1243  serang jokowi kawan kawan serang urus main tim...
# 572   pensiun maarten paes main naturalisasi kerja i...
# 2270  mikirnya peter main liga eropa belanda turun i...
# 364   pungkur kualitas visi misi main turun main ero...
# 1664  main liga jerman bintang muda naturalisasi kab...
# 2157  kemarin misuh main turun darah indonesia bela ...
# 872   pssi kurang naturalisasi main timnas indonesia...
# 1891  harus rekrut main turun rekrut main main baik ...

# %%
# Jumlah Tweet
print("Jumlah Tweet yang kami peroleh:", df_final.shape[0]," Tweet")
# Out:
# Jumlah Tweet yang kami peroleh: 2537  Tweet

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2537 entries, 0 to 2536
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   created_at        2537 non-null   object
#  1   favorite_count    2537 non-null   int64
#  2   full_text         2537 non-null   object
#  3   location          1556 non-null   object
#  4   quote_count       2537 non-null   int64
#  5   reply_count       2537 non-null   int64
#  6   retweet_count     2537 non-null   int64
#  7   tweet_url         2537 non-null   object
#  8   user_id_str       2537 non-null   int64
#  9   username          2537 non-null   object
#  10  sentiment         2537 non-null   int64
#  11  username_in_teks  2537 non-null   object
#  12  hastag_in_teks    2537 non-null   object
#  13  teks_new          2537 non-null   object
#  14  teks_slang1       2537 non-null   object
#  15  teks_slang2       2537 non-null   object
#  16  teks_slang3       2537 non-null   object
#  17  teks_rapih        2537 non-null   object
#  18  clean_teks        2537 non-null   object
#  19  stem_teks         2537 non-null   object
# dtypes: int64(6), object(14)
# memory usage: 396.5+ KB

# %%
# Menghapus kolom yang tidak digunakan
df_final = df_final.drop(columns=['teks_slang1', 'teks_slang2', 'teks_slang3', 'user_id_str', 'username_in_teks'])

# Mapping angka ke label sentimen
sentiment_mapping = {1: 'Negatif', 2: 'Netral', 3: 'Positif'}

# Menambahkan kolom label sentimen berdasarkan mapping
df_final['sentiment_label'] = df_final['sentiment'].map(sentiment_mapping)

# Mengonversi kolom 'created_at' ke format datetime
df_final['created_at'] = pd.to_datetime(df_final['created_at'], format='%a %b %d %H:%M:%S +0000 %Y')

# Mengonversi string menjadi list
df_final['hastag_in_teks'] = df_final['hastag_in_teks'].str.lower().apply(ast.literal_eval)

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2537 entries, 0 to 2536
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   created_at       2537 non-null   datetime64[ns]
#  1   favorite_count   2537 non-null   int64
#  2   full_text        2537 non-null   object
#  3   location         1556 non-null   object
#  4   quote_count      2537 non-null   int64
#  5   reply_count      2537 non-null   int64
#  6   retweet_count    2537 non-null   int64
#  7   tweet_url        2537 non-null   object
#  8   username         2537 non-null   object
#  9   sentiment        2537 non-null   int64
#  10  hastag_in_teks   2537 non-null   object
#  11  teks_new         2537 non-null   object
#  12  teks_rapih       2537 non-null   object
#  13  clean_teks       2537 non-null   object
#  14  stem_teks        2537 non-null   object
#  15  sentiment_label  2537 non-null   object
# dtypes: datetime64[ns](1), int64(5), object(10)
# memory usage: 317.2+ KB

# %%
# Mengurutkan data berdasarkan Waktu
df_final = df_final.sort_values(by='created_at')
df_final.reset_index(drop=True, inplace=True)

# %%
# Menghitung total engagement per tweet
df_final['engagement'] = df_final['quote_count'] + df_final['reply_count'] + df_final['retweet_count'] + df_final['favorite_count']

# %% [markdown]
# ## Visualisasi (Analisis Tweet)

# %% [markdown]
# ### Jumlah Tweet Harian

# %%
# Menyiapkan kolom untuk format tanggal harian
df_final['tanggal'] = df_final['created_at'].dt.strftime('%d %b')
# Menghitung banyak tweet perhari
tweet_per_hari = df_final.groupby('tanggal').size()
# Convert the result into a DataFrame and rename the column
tweet_per_hari = tweet_per_hari.reset_index(name='size')

# %%
# Create a figure with one axis
fig, ax = plt.subplots(figsize=(10, 6))

# Barplot
sns.barplot(x='tanggal', y='size', data=tweet_per_hari, ax=ax, color='salmon')

# Lineplot on top of the barplot
sns.lineplot(x='tanggal', y='size', data=tweet_per_hari, ax=ax, color='red', marker='o')

# Annotate the bars
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}',  # Menghapus desimal dan mengubah ke integer
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='bottom',  # Posisikan tepat di atas bar
                fontsize=8, color='black',  # Ukuran font lebih kecil
                xytext=(0, 5), textcoords='offset points')  # Jarak sedikit di atas bar

# Add labels and title
ax.set_xlabel('Tanggal')
ax.set_ylabel('Jumlah Tweet')
ax.set_title('Barplot dan Lineplot Jumlah Tweet per Hari')

# Display the plot
plt.xticks(rotation=45)  # Rotate the x-axis labels for better visibility
plt.tight_layout()
plt.show()

# %% [markdown]
# Interpretasi:
#
# - Isu naturalisasi pemain timnas mulai ramai dibahas khususnya di media sosial Twitter (X) pada bulan September, yang dipicu oleh laga kualifikasi Piala Dunia (5 dan 10 September).
#
# - Lonjakan besar terjadi pada 12 September (162 tweet) dan 13 September (282 tweet) karena statement yang dikeluarkan oleh peter gontha menunjukkan ketidaksetujuan terhadap kebijakan PSSI terkait naturalisasi Timnas.

# %% [markdown]
# ### Tagar Populer

# %%
# Menggabungkan semua hashtag ke dalam satu list besar
all_hashtags = [hashtag for sublist in df_final['hastag_in_teks'] for hashtag in sublist]

# Menghitung frekuensi hashtag
hashtag_counts = Counter(all_hashtags)

# Mengonversi ke DataFrame untuk visualisasi
hashtag_df = pd.DataFrame(hashtag_counts.items(), columns=['Hashtag', 'Count'])

# Mengambil 30 hashtag terbanyak
hashtag_df = hashtag_df.nlargest(30, 'Count')

# Membuat treemap
plt.figure(figsize=(15, 6))
squarify.plot(sizes=hashtag_df['Count'], label=hashtag_df['Hashtag'], alpha=0.7, color=plt.cm.viridis(hashtag_df['Count'] / max(hashtag_df['Count'])))

# Menambahkan judul dan label
plt.title('Top 30 Hashtags Treemap')
plt.axis('off')  # Menonaktifkan axis

# Tampilkan plot
plt.show()

# %% [markdown]
# Interpretasi:
#
# Tagar populer #timnasday, #naturalisasi, dan #timnasindonesia mencerminkan pembahasan isu naturalisasi pemain dalam konteks antusiasme dan dukungan terhadap timnas Indonesia selama pertandingan.

# %% [markdown]
# ### Visualisasi Jaringan Sosial Netizen X

# %%
import networkx as nx
# Draw the Tweet Graph
G=nx.Graph()
for i, tweet in tqdm(df_final.iterrows()):
    if tweet.username not in G.nodes():
        G.add_node(tweet.username)
    mentionS =  re.findall("@([a-zA-Z0-9]{1,15})", tweet['full_text'])
    for mention in mentionS:
        if "." not in mention: #skipping emails
            usr = mention.replace("@",'').strip()
            if usr not in G.nodes():
                G.add_node(usr)
            G.add_edge(tweet.username, usr)
Nn=G.number_of_nodes();Ne=G.number_of_edges()
print('Finished. There are %d nodes and %d edges in the Graph.' %(Nn,Ne))
# Out:
# 2537it [00:00, 5796.55it/s]
# Finished. There are 2234 nodes and 1852 edges in the Graph.

# %%
import networkx as nx

# Ekspor graf ke file GraphML untuk nantinya diproses dalam software Gephi
nx.write_graphml(G, "twitter_graph_timnas.graphml")

# %%
# hasil output dari Gephi di upload ke dalam link drive pada url berikut
# https://drive.google.com/file/d/1MjrTWYewA_JNedDIQK4WYpCO5H6d-aRk/view?usp=drive_link

import requests
# Tautan unduhan langsung
id = "1MjrTWYewA_JNedDIQK4WYpCO5H6d-aRk"
url = f"https://drive.google.com/uc?id={id}"
output_path = "/content/graph.svg"

# Unduh file
response = requests.get(url)
with open(output_path, "wb") as file:
    file.write(response.content)

print(f"File SVG berhasil diunduh: {output_path}")
# Out:
# File SVG berhasil diunduh: /content/graph.svg

# %%
# Menampilkan Hasil Output
from IPython.display import HTML

# Path ke file SVG
svg_path = "/content/graph.svg"

# Baca isi file SVG
with open(svg_path, "r") as file:
    svg_content = file.read()

# HTML dengan slider dan SVG otomatis berada di tengah
html_content_with_centering = f"""<div style="border: 1px solid black; width: 200vh; height: 175vh; display: flex; flex-direction: column; align-items: center; justify-content: center; overflow: hidden;">
    <div id="svgContainer" style="display: flex; justify-content: center; align-items: center; transform: scale(0.45); transform-origin: center;">
        {svg_content}
    </div>
</div>
"""

# Tampilkan dengan centering dan margin top
display(HTML(html_content_with_centering))
# Out:
# <div style="border: 1px solid black; width: 200vh; height: 175vh; display: flex; flex-direction: column; align-items: center; justify-content: center; overflow: hidden;">
#     <div id="svgContainer" style="display: flex; justify-content: center; align-items: center; transform: scale(0.45); transform-origin: center;">
#         <?xml version="1.0" encoding="UTF-8"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#     "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd" >
# <svg contentScriptType="text/ecmascript" width="3973.2188"
#      xmlns:xlink="http://www.w3.org/1999/xlink" zoomAndPan="magnify"
#      contentStyleType="text/css"
#      viewBox="-2034.218628 -1723.000000 3973.218750 3541.000000" height="3541.0"
#      preserveAspectRatio="xMidYMid meet" xmlns="http://www.w3.org/2000/svg"
#      version="1.1">
#     <g id="edges">
#         <path fill="none" stroke-width="2.0"
#               d="M 184.882538,-563.630432 L 76.249008,-649.543396"
#               class="id_HeriWidayanto5 id_idextratime" stroke-opacity="1.0"
#               stroke="#ffbfe5"/>
#         <path fill="none" stroke-width="2.0"
#               d="M 188.265961,-551.062744 L 131.047729,-405.998322"
#               class="id_HeriWidayanto5 id_bliblidotcom" stroke-opacity="1.0"
#               stroke="#ffbfe5"/>
#         <path fill="none" stroke-width="2.0"
#               d="M 26.348934,-619.923462 L 98.035713,-201.604553"
#               class="id_idextratime id_okezonenews" stroke-opacity="1.0"
#               stroke="#ffbfe5"/>
#         <path fill="none" stroke-width="2.0"
#               d="M 87.101379,-667.721924 L 207.264023,-615.885315"
#               class="id_idextratime id_wpj4ck" stroke-opacity="1.0"
#               stroke="#ffbfe5"/>
#         <path fill="none" stroke-width="2.0"
#               d="M 70.012825,-642.533203 L 410.498047,-302.370636"
#               class="id_idextratime id_sansan_3110" stroke-opacity="1.0"
#               stroke="#ffbfe5"/>
#         <path fill="none" stroke-width="2.0"
#               d="M 84.818741,-662.877075 L 287.564209,-559.037292"
#               class="id_idextratime id_akuratco" stroke-opacity="1.0"
#               stroke="#ffbfe5"/>
#         <path fill="none" stroke-width="2.0"
#               d="M -2.444166,-779.498230 L -48.779865,-1023.971313"
#               class="id_idextratime id_kaenjete0" stroke-opacity="1.0"
#               stroke="#ffbfe5"/>
#         <path fill="none" stroke-width="2.0"
#               d="M -50.470249,-648.954224 L -419.952209,-351.122803"
#               class="id_idextratime id_ardhiasaY" stroke-opacity="1.0"
#               stroke="#ffbfe5"/>
#         <path fill="none" stroke-width="2.0"
#               d="M 43.965240,-774.626587 L 154.840607,-1039.461670"
#               class="id_idextratime id_lanaaeyra" stroke-opacity="1.0"
#               stroke="#ffbfe5"/>
#         <path fill="none" stroke-width="2.0"
#               d="M 43.620514,-774.769958 L 175.753113,-1094.505127"
#               class="id_idextratime id_our_hoseokiie" stroke-opacity="1.0"
#               stroke="#ffbfe5"/>
#         <path fill="none" stroke-width="2.0"
#               d="M 24.562088,-780.037231 L 68.626465,-1076.810425"
#               class="id_idextratime id_bukanbudakk" stroke-opacity="1.0"
#               stroke="#ffbfe5"/>
#         <path fill="none" stroke-width="2.0"
#               d="M 62.131351,-764.069885 L 153.983673,-883.314697"
#               class="id_idextratime id_emhaputri_98" stroke-opacity="1.0"
#               stroke="#ffbfe5"/>
#         <path fill="none" stroke-width="2.0"
#               d="M -38.702995,-762.576904 L -242.087463,-1011.037415"
#               class="id_idextratime id_ero_semut" stroke-opacity="1.0"
#               stroke="#ffbfe5"/>
#         <path fill="none" stroke-width="2.0"
#               d="M 92.671150,-712.917175 L 191.283112,-729.036499"
#               class="id_idextratime id_Anakpertamaa__" stroke-opacity="1.0"
#               stroke="#ffbfe5"/>
#         <path fill="none" stroke-width="2.0"
#               d="M 3.611497,-780.410583 L -34.192249,-1117.254028"
#               class="id_idextratime id_dwimeldwi" stroke-opacity="1.0"
#               stroke="#ffbfe5"/>
#         <path fill="none" stroke-width="2.0"
#               d="M 54.626274,-769.207031 L 184.901398,-984.519836"
#               class="id_idextratime id_Ryogartshop1" stroke-opacity="1.0"
#               stroke="#ffbfe5"/>
#         <path fill="none" stroke-width="2.0"
#               d="M 93.567993,-705.009399 L 363.498962,-722.263062"
#               class="id_idextratime id_wojarskj" stroke-opacity="1.0"
#               stroke="#ffbfe5"/>
#         <path fill="none" stroke-width="2.0"
#               d="M -41.755424,-759.948975 L -160.952698,-891.637634"
#               class="id_idextratime id_Aly13738154" stroke-opacity="1.0"
#               stroke="#ffbfe5"/>
#         <path fill="none" stroke-width="2.0"
#               d="M 93.110466,-709.866394 L 267.506042,-731.604919"
#               class="id_idextratime id_Gaviel27" stroke-opacity="1.0"
#               stroke="#ffbfe5"/>
#         <path fill="none" stroke-width="2.0"
#               d="M 92.676201,-712.886230 L 427.906464,-767.550598"
#               class="id_idextratime id_hwangcloves" stroke-opacity="1.0"
#               stroke="#ffbfe5"/>
#         <path fill="none" stroke-width="2.0"
#               d="M -67.822128,-689.970276 L -487.480042,-638.516174"
#               class="id_idextratime id_ndarusipit28" stroke-opacity="1.0"
#               stroke="#ffbfe5"/>
#         <path fill="none" stroke-width="2.0"
#               d="M -24.229305,-772.041382 L -90.106972,-901.004944"
#               class="id_idextratime id_greyx00" stroke-opacity="1.0"
#               stroke="#ffbfe5"/>
#         <path fill="none" stroke-width="2.0"
#               d="M 70.156181,-756.997864 L 239.946457,-925.779541"
#               class="id_idextratime id_RidlaAinur" stroke-opacity="1.0"
#               stroke="#ffbfe5"/>
#         <path fill="none" stroke-width="2.0"
#               d="M 41.041637,-623.890442 L 182.883865,-244.409912"
#               class="id_idextratime id_officialinews_" stroke-opacity="1.0"
#               stroke="#ffbfe5"/>
#         <path fill="none" stroke-width="2.0"
#               d="M 92.697662,-686.921021 L 129.532791,-680.976990"
#               class="id_idextratime id_amsiong41" stroke-opacity="1.0"
#               stroke="#ffbfe5"/>
#         <path fill="none" stroke-width="2.0"
#               d="M -28.918114,-769.447388 L -169.667938,-1005.123230"
#               class="id_idextratime id_Banumustafa24" stroke-opacity="1.0"
#               stroke="#ffbfe5"/>
#         <path fill="none" stroke-width="2.0"
#               d="M 24.932383,-619.693604 L 103.004837,-110.089264"
#               class="id_idextratime id_Liverpoolcs_id" stroke-opacity="1.0"
#               stroke="#ffbfe5"/>
#         <path fill="none" stroke-width="2.0"
#               d="M -12.382842,-776.953857 L -43.589279,-873.072754"
#               class="id_idextratime id_hehe78_9" stroke-opacity="1.0"
#               stroke="#ffbfe5"/>
#         <path fill="none" stroke-width="2.0"
#               d="M 41.225750,-775.715393 L 83.835930,-888.875854"
#               class="id_idextratime id_Anachaudhry07" stroke-opacity="1.0"
#               stroke="#ffbfe5"/>
#         <path fill="none" stroke-width="2.0"
#               d="M 52.706585,-770.332886 L 142.030380,-927.549744"
#               class="id_idextratime id_TayyabaZee_" stroke-opacity="1.0"
#               stroke="#ffbfe5"/>
#         <path fill="none" stroke-width="2.0"
#               d="M 75.816460,-750.673706 L 204.191635,-853.996521"
#               class="id_idextratime id_IanJoeli" stroke-opacity="1.0"
#               stroke="#ffbfe5"/>
#         <path fill="none" stroke-width="2.0"
#               d="M 19.891880,-780.592712 L 34.280212,-941.131531"
#               class="id_idextratime id_asrulsy_" stroke-opacity="1.0"
#               stroke="#ffbfe5"/>
#         <path fill="none" stroke-width="2.0"
#               d="M 54.363461,-769.365356 L 109.238899,-860.840820"
#               class="id_idextratime id_Fer_th_silence" stroke-opacity="1.0"

# %% [markdown]
# Interpretasi:
#
# Berdasarkan analisis jaringan, beberapa akun Twitter (X) dengan degree tertinggi sering disebut atau di-reply dalam diskusi terkait topik naturalisasi pemain sepak bola. Akun-akun tersebut dapat dikelompokkan berdasarkan peran mereka:
#
# - Akun media: Akun seperti idextratime, indostransfer, gilabola, panditfootball, sukanyepak, dan kegblgunfaedh berperan sebagai pusat penyebaran informasi. Mereka menjadi referensi utama bagi Netizen.
#
# - Tokoh sentral: ErickThohir dan PeterGontha sering menjadi subjek pembicaraan.
#
# - Akun pribadi aktif: Akun seperti pangeransiahaan, pray_thekid, dan FahmiAgustian  memberikan pandangan atau tanggapan yang menarik perhatian diskusi.
#
# Narasi yang muncul dalam pembicaraan ini mencakup beberapa tema utama, yaitu:
#
# 1. Rasa bangga masyarakat terhadap performa Timnas Indonesia, terutama setelah kehadiran pemain naturalisasi.
# 2. Kritik terhadap kebijakan naturalisasi, termasuk dari pengamat sepak bola dan Peter Gontha, yang mempertanyakan langkah PSSI di bawah kepemimpinan Erick Thohir.
# 3. Informasi tentang calon pemain baru, yang menjadi daya tarik utama bagi diskusi di antara pengguna Twitter.
# 4. Perbandingan internasional, di mana muncul opini bahwa Timnas Indonesia memiliki keunggulan dibandingkan negara lain.

# %%
# Diperoleh beberapa akun dengan mention terbanyak (dilihat dari degree yang besar)
list_akun = ['kegblgnunfaedh','erickthohir','Indostransfer','gilabola', 'pangeransiahaan','panditfootball','idextratime','sukanyepak','PeterGontha','FahmiAgustian','pray'] # akun yang ingin diperiksa

# Mencari tweet yang melakukan mention yang kemudian akan diperoleh tweet apa yang di-reply oleh Netizen X
for i in range(len(list_akun)):
    print(f"[{list_akun[i]}]")
    nama_akun = list_akun[i]
    isi_tweet = df_final[df_final['full_text'].str.contains('@'+nama_akun, case=False, na=False)].head(5) # head untuk kustomisasi jumlah tweet yang ditarik
    listtweet = list(isi_tweet['full_text'])
    listurltweet = list(isi_tweet['tweet_url'])
    for j in range(len(listtweet)):
       print(f"{j+1}. Link [{listurltweet[j]}] : {listtweet[j]}")
# Out:
# [kegblgnunfaedh]
# 1. Link [https://x.com/aryyyyymaulanaa/status/1834912776005075192] : @kegblgnunfaedh yang dikritik si batu ini adalah kurangnya perhatian pelatihan para atlit sehingga harus ambil pemain naturalisasi. naturalisasi memang jalan pintas tapi gak salah juga ko lagipula pemain yang diambil punya keturunan Indonesia
# 2. Link [https://x.com/Fauziahmdb/status/1834966011004830179] : @restafajri @kegblgnunfaedh Menurut gw salah sih dia cuma liat timnas senior dia mengatakan regenerasi nyatanya u17 u20 dan U23 kita cukup membanggakan rata pemain kita itu karirnya abis di umur 25 keatas yg seharusnya jadi masa emasnya pemain bola tujuan naturalisasi ini supaya Indonesia dilirik-
# 3. Link [https://x.com/heruwicaksono41/status/1834966384037753103] : @kegblgnunfaedh Seoranf politik gak pantes komen tentang sepak bola yg bukan di bidangnya timnas kita mau maju di jatuhin sma orang kita lgi pula mreka yg naturalisasi ada darah indonesia sah sesuai undang gw tau prancis sepak bola nya hebat tanpa memandang mbbape dan yg lain dari negara ap
# 4. Link [https://x.com/toobad4you_/status/1835000392062820845] : @malakaf46 @speakbola_id @kegblgnunfaedh ya bukan karna ga perlu repot2 jg bang. Kalo gamau repot jangan jadi PSSI. emang diatas kertas bukan barang haram naturalisasi. tapi mungkin maksud RG ini tamparan buat seluruh entitas yg ada di sepak bola indonesia baik badan persepak bolaan dan para pemain.
# 5. Link [https://x.com/ddngjnrt/status/1835008271981461975] : @kegblgnunfaedh Gini pak kebanggaan nasional mana yang bangga dengan rank 174 dunia dengan pemain lokal pak? Justru kita bangga rank indonesia sekarang peringkat 129 dan masih bisa naik lagi udahlah pak ini bukan ranah bapak jangan ikut campur timnas france 100% naturalisasi dan semua bngga
# [erickthohir]
# 1. Link [https://x.com/TrilaksonoGatot/status/1832072271516832003] : Breaking News: Ketua PSSI @erickthohir sudah bertemu bersalaman &amp; makan malam bersama dengan Mees Hilgers &amp; Eliano Reijnders. Pertanda Naturalisasi keduanya semakin mendekati kenyataan untuk menjadi pemain Timnas Indonesia selanjutnya. Pic: IG Erick Thohir Paes mancini Idzes https://t.co/ktysqvyWjF
# 2. Link [https://x.com/Rexthatch/status/1832072578309214563] : Resmi! Erick Thohir Umumkan Mees Hilgers dan Eliano Reijnders sebagai Calon Pemain Naturalisasi Timnas Indonesia KELAZZZZ PAK @erickthohir https://t.co/aO7osXAmdS
# 3. Link [https://x.com/officialinews_/status/1832073831823151476] : @erickthohir Mees Hilgers dan Eliano Reijnders Calon Pemain Naturalisasi Baru Timnas Indonesia https://t.co/hdc3Pb7ewR
# 4. Link [https://x.com/akuratco/status/1832075622673519026] : @idextratime @erickthohir Erick Thohir Akui PSSI Sedang Proses Naturalisasi Dua Pemain Keturunan Baru untuk Timnas Indonesia https://t.co/ZDPLCM6FMt
# 5. Link [https://x.com/foxintheboxidn/status/1832077738343285097] : RESMI! Kalo udah salaman udah tau artinya apa kan? Mees Hilgers dan Eliano Reijnders akan jalani naturalisasi WNI untuk gabung Timnas Indonesia FYI Mees Hilgers akan jadi pemain termahal di Asia Tenggara! Hormat buat PSSI dan jajarannya @pssi @erickthohir @erickthohir https://t.co/nkeDzw5GaM
# [Indostransfer]
# 1. Link [https://x.com/Dhyz10/status/1831674688654995689] : @Indostransfer Bang jepang ngeri..pemain pro jepang keturunan Indonesia ada ga sih min kaya Belanda kan banyak nih
# 2. Link [https://x.com/officialinews_/status/1832077246619873669] : @Indostransfer Mees Hilgers dan Eliano Reijnders Calon Pemain Naturalisasi Baru Timnas Indonesia https://t.co/hdc3Pb7ewR
# 3. Link [https://x.com/dhonnie_can/status/1832196634442346764] : @Indostransfer Mohon maaf tapi bagaimana Indonesia 10 tahun ke depannya? Ketika para pemain keturunan sudah berumur
# 4. Link [https://x.com/nananghandoyo6/status/1834109938110743001] : @Indostransfer scr administrasi mereka wni ga langgar statuta fifa ada darah/keturunan indonesia tulus berjuang dan sejauh ini performa timnas naik signifikan. trus musti gmn? soal pemain lokal ya ttp dipilih koq selama skill memenuhi. pembinaan liga ya ayo dibenahi smbl jln
# 5. Link [https://x.com/YudhArt234/status/1834110218298630288] : @Indostransfer Ambil pemain keturunan bukan solusi jangan pnjang itu gue setuju. Tpi kita perlu untuk angkat pamor sepakbola indonesia &amp; cara ini berhasil biar anak anak kecil ini suka tinggal kita siapkan fasilitasnya untuk mengakomondir minat anak2 ini. Momentum perubahannya itu yg penting
# [gilabola]
# 1. Link [https://x.com/AnakCroco/status/1832562688045805618] : @bimokresno @gilabola_ina PSSI kan punya rencana jangka pendek dan jangka panjang Untuk memenuhi ekspektasi para penggemar sepakbola timnas saat ini yaitu dengan menarik pemain yang memiliki darah keturunan Indonesia Nah jangka panjangnya pak ET lagi membangun kompetisi dari usia muda Santai aja
# 2. Link [https://x.com/aardwi15/status/1832617285812679030] : @gilabola_ina Kalo di indonesia semisal udh salaman sama @erickthohir udh pasti terealisasi kalo di malaysia ngga tau gimana prosesnya kayaknya dari dlu update pemain2 keturunan tapi ujung2nya naturalisasi pemain dari liga lokal
# 3. Link [https://x.com/JimmYNWA_97/status/1832740173127233683] : @gilabola_ina 1. Pemain adalah Indo 2. Bermain di Eropa 3. Kualitas bersaing dengan pemain lain dari berbagai negara &amp; benua lain di Eropa. 4. Timnas Indonesia naik level 5. SDM mulai melek Timnas hebat di Eropa juga tidak lepas dari pemain keturunan bahkan Belanda juga punya pemain Indo.
# 4. Link [https://x.com/ajikxs/status/1832747380137140694] : @gilabola_ina Butuh proses dari yang terkecil menjadi lebih besar banyak pro dan kontra perihal tindakan naturalisasi tapi syukur untuk olahraga Bola Sepak Indonesia sekarang sudah menemukan hasil semoga ya bisa ditingkatkan lagi dalam bentuk timnas dan liga
# 5. Link [https://x.com/LutviAdi/status/1832758349324329228] : @gilabola_ina Kenapa harus sementara di eropa banyak timnas gede pada pemain keturunan selama ada darah indonesia boleh aja asal adil aja seleksinya
# [pangeransiahaan]
# 1. Link [https://x.com/Tiarniama/status/1834474766650208458] : @ltmoerdani @pangeransiahaan Karena udah terlalu sering dari dulu kepemimpinan PSSI yang dulu juga paling sering naturalisasi pemain asing yg ga ada hubungan sama indonesia entah itu untuk kepentingan klub atau untuk timnas jadi orang indonesia terlalu fasih buat nyebut naturalisasi.
# 2. Link [https://x.com/matjanmi/status/1834488271562572018] : @pangeransiahaan Yg benci/teriak2 dgn naturalisasi/diaspora biasa para broker yg jelas2 perusak sepak bola Indonesia demi Uang. Fakta. !
# 3. Link [https://x.com/SuryoSasmojo/status/1834489415638679993] : @pangeransiahaan Sbtulby gmslh apapun model 'naturalisasi'nya. Kta smua psti trima siapapun yg mau bela timnas dgn/tanpa darah Indonesia. Yg jd mslh adl kl federasi trlalu mngndalkan naturalisasi sbg arus utama indikator prestasi tnpa adny rncna pngmbangan &amp; prbaikan kmpetisi dmestik yg jelas.
# 4. Link [https://x.com/xxrzkynoxx/status/1834490342382694502] : @pangeransiahaan Kalo konteksnya pemain imigran ya betul memang beda tapi ada juga kan pemain yg lahir di A tapi memilih untuk membela negara B karna dia juga punya keturunan dari negara B dan itu ada kok jadi ya ga masalah juga mngkin yg mendekati Indonesia ya Maroko
# 5. Link [https://x.com/r_keciillll/status/1834491298319040628] : @ltmoerdani @pangeransiahaan Diaspora itu orangnya Naturalisasi itu prosesnya (dari pemberkasan dpr kepres hingga sumpah itu namanya proses naturalisasi) Emang semua pemain diaspora di timnas yg sekarang itu punya darah indonesia tapi mereka semua melakukan yg namanya proses naturalisasi (kecuali elkan)
# [panditfootball]
# 1. Link [https://x.com/orang_dalam85/status/1831916876244660344] : @jvstforvan @panditfootball Pelatih STY seharusnya malu karena belum pernah juara AFF selain itu skuad timnas saat ini hanya mengandalkan pemain naturalisasi...seharusnya STY out ttd : legenda sepak bola indonesia lord of the king 0 goal anjas asmara
# 2. Link [https://x.com/a_ibra76/status/1834590204742775261] : @panditfootball @zenrs @SeppGinz @PeterGontha @Ekomaung @PanditFPL @Support ga penting amat ni topic.... ribut soal naturalisasi pemain bola tapi saat atlet cabor lain meninggalkan Indonesia dan memilih bela negara lain tuan ini santuy... exp: Mia Audina (badminton). seingat saya Indonesia tidak menggunakan sistem kewarganegaraan ganda.
# 3. Link [https://x.com/timunlautsopan/status/1834903572171178414] : @panditfootball @_BangFu namany beda pendapat wajar sih. emang jgn cuman fokus di timnas aja tp bagaimana akademi di indonesia bisa bagus dan maju jadi gk selalu ngandelin naturalisasi dari luar. tp udah lumayan ada perkembangan si apalagi ada bali7s kemaren buat youth tournament.
# 4. Link [https://x.com/muharsyadd/status/1834907891679346993] : @panditfootball @_BangFu Mau Indonesia lolos ke Piala Dunia dengan skuad yg seperti ini atau mungkin dengan ditambah pemain keturunan lagi saya tetap sepakat dengan pernyataan Bang Fu. Pengalaman PSSI yg dulu² seringnya cuma nyari sensasi lewat timnas doang. Lini-lini sepak bola dibiarkan sekadar ada.
# 5. Link [https://x.com/apaini89246277/status/1834908156297986504] : @panditfootball @_BangFu serampangan? mayoritas pemain naturalisasi sekarang punya darah indonesia kecuali paes yang neneknya asli bule cuma numpang lahir di kediri 🇮🇩 kritik kompetisi dan pembinaan pemain muda emang harus dilakukan tapi tolong kurangi caper ke timnas yang lagi berjuang ke masuk WC26
# [idextratime]
# 1. Link [https://x.com/HeriWidayanto5/status/1830222229914923099] : @idextratime @bliblidotcom Indonesia bisa tanpa pemain keturunan Halah tai kucing
# 2. Link [https://x.com/okezonenews/status/1831558687351304268] : @idextratime @bliblidotcom BREAKING NEWS! Shin Tae-yong Konfirmasi Timnas Indonesia Kedatangan 2 Pemain Naturalisasi Tambahan https://t.co/CDRhR2w8wC
# 3. Link [https://x.com/wpj4ck/status/1831786756204851456] : @idextratime @bliblidotcom Melihat kesuksesan naturalisasi di timnas Indonesia knp ga didorong sekalian utk perubahan UUD yg memungkinkan menaturalisasi Presiden menteri dan pejabat Idn dah eneg bgt lihat kinerja pejabat kita
# 4. Link [https://x.com/sansan_3110/status/1832054126064320803] : @hwangcloves @caluxcreeck @idextratime Yang pakai kacamata Arya Sinulingga (Exco PSSI). Yang satunya Yussa Nugraha (Youtubers yang sering interview pemain keturunan Indonesia).
# 5. Link [https://x.com/akuratco/status/1832075622673519026] : @idextratime @erickthohir Erick Thohir Akui PSSI Sedang Proses Naturalisasi Dua Pemain Keturunan Baru untuk Timnas Indonesia https://t.co/ZDPLCM6FMt
# [sukanyepak]
# 1. Link [https://x.com/Chalid76835244/status/1834573915236274203] : @sukanyepak_bola Sepakbola internasional mana yg naturalisasi seperti yg di lakukan Indonesia? Kalau hny 1-2 pemain iy mmg bnyk yg sprt indonesia??? lawan Arab dan Australia brp pemain naturalisasinya?
# 2. Link [https://x.com/ImamAgusfaisl/status/1834589034557194744] : @JayaManula @sukanyepak_bola Gue lebih sedih bangsa sendiri gak mampu bersaing sama pemain naturalisasi padahal pemain indonesia pas muda bagus bagus eh menginjak senior seteah mengenal popularitas langsung redup makan yg penting halal gak ngitung nutrisi latihan males2an disiplin atlet gak ada
# 3. Link [https://x.com/MattPambudhi/status/1834621993226002586] : @sukanyepak_bola Ribet kok mereka ini padahal naturalisasi di sepak bola itu hal yg wajar dan boleh masih aja dipermasalahin lu lihat noh pemain 90 menit jatuh bangun di lapangan fighting spiritnya ada buat Indonesia di bilang grup yg tidak kita idealkan sungguh statement yg DUNGU !!
# 4. Link [https://x.com/arvand90/status/1834631850633081078] : @servinssazure @sukanyepak_bola yakin paes ada darah indonesia nya ? kalau cuma 30% pemain naturalisasi masih OK tp kalau sudah 80% naturalisasi itu namanya frustasi dalam pembinaan !
# 5. Link [https://x.com/arvand90/status/1834635032952209706] : @servinssazure @sukanyepak_bola naturalisasi dulu tuh ngga banyak mrk telah lama menunjukan kecintaan nya dl thd indonesia br dinaturalisasi skr pernah ke indonesia aja mungkin blm bahasa indonesia ngga bs langsung di iming2 masuk timnas !
# [PeterGontha]
# 1. Link [https://x.com/a_ibra76/status/1834590204742775261] : @panditfootball @zenrs @SeppGinz @PeterGontha @Ekomaung @PanditFPL @Support ga penting amat ni topic.... ribut soal naturalisasi pemain bola tapi saat atlet cabor lain meninggalkan Indonesia dan memilih bela negara lain tuan ini santuy... exp: Mia Audina (badminton). seingat saya Indonesia tidak menggunakan sistem kewarganegaraan ganda.
# 2. Link [https://x.com/PyRa39389/status/1834733359039463851] : @msaid_didu @PeterGontha Saya sepaham. Sebenarnya di masyarakat luas banyak yg merasa aneh juga dengan banyaknya pemain naturalisasi. Timnas Indonesia tapi banyak pemain yg tidak bisa bahasa Indonesia apalagi lagu kebangsaan. Lagu kebangsaanpun dihayati hanya oleh penonton saja.
# 3. Link [https://x.com/Mocha30258022/status/1834828619975368760] : @PyRa39389 @msaid_didu @PeterGontha Pemain timnas yg keturunan sudah bsa dan hafal Indonesia raya kok
# 4. Link [https://x.com/iyehmilanistii/status/1834845505891057857] : @msaid_didu @PeterGontha sbenarnya memang saya lebih bangga kalo pemain nya dari liga lokal semua TAPI udah berpuluh2 tahun mereka tidak mampu.. skrg kita.coba memanfaat kan keturunan toh mereka ada darah indonesia nya ko toh bukan kita doang yg pakai cara gini.. ayolah cerdas dikit ini INDONESIA ko
# 5. Link [https://x.com/GabunganL927/status/1834851580941943240] : @msaid_didu @PeterGontha sangat sependapat dgn pak peter. trus apakah kalian bangga dgn timnas (naturalisasi) sekarang? Terusterang aku Tidak...! Sejelek-jelek timnas asli indonesia aku lebih suka... Hanyasaja perlu profesional dlm rekrutmen dan latihan fisik.
# [FahmiAgustian]
# 1. Link [https://x.com/muhamadrdani/status/1835449263708688558] : @Rumputtliarr_ @FahmiAgustian Memang benar naturalisasi skrng itu bukan pemain yg ga ada darah indonesianya rata2 keturunan indonesia semua (kecuali paes). Yg jadi sorotan bung rocky itu timnas di dominasi bukan hasil bibit binaan dalam negeri sendiri.
# 2. Link [https://x.com/afim4ul/status/1835452805160796513] : @FahmiAgustian Jangan bahasa bola bisa ga sih stop sekarang sampai tahun 2026 biar timnas makin fokus ga usah bahas hal lain intinya stasiun tv atau apalah stop dulu undang undang hal hal tentang bola karena hampir yang diributin itu naturalisasi bukan pembinaan senggol basket juga
# 3. Link [https://x.com/deal_lahh/status/1835457949965410728] : @AdiX404 @BrantKenn @donicaturp54300 @SeptiyanWisnu @Kananmasuksurga @FahmiAgustian padahal jelas jelas mereka punya darah Indonesia bukan naturalisasi orang yang gada kaitannya sama Indonesia! Kayak verdonk ayahnya orang aceh. Dia dengan tulus membela timnas. Gila lo masih bilang dia dari bangsa lain. Shut your mouth!
# 4. Link [https://x.com/IndonesiaF56951/status/1835461200840368171] : @FahmiAgustian Pro &amp; kontra naturalisasi pasti ada namun tidak ada salahnya mendukung seluruh pemain timnas selagi mereka berjuang di level piala dunia selagi timnas berjuang pembinaan usia muda perbaikan kualitas liga wasit stadion &amp; pemberantasan mafia bola tetap harus diutamakan.
# 5. Link [https://x.com/fnvprtma/status/1835462682880934319] : @AdiX404 @BrantKenn @donicaturp54300 @SeptiyanWisnu @Kananmasuksurga @FahmiAgustian Eh orang aring gue kasih tau ye. Sekarang yang di naturalisasi itu punya darah indonesia artinya mereka juga berhak membela timnas indo. Ini bukan naturalisasi jaman jebot yang gaada darah indonya sama sekali. Lu rasis namanya kalau masih membeda-bedakan kaya gitu
# [pray]
# 1. Link [https://x.com/phingan200/status/1832679032607142187] : @pray_thekid Kalo cuma mau juara tapi dgn system amburadul mending kontrak team eropah sekalian. Naturalisasi terbatas. Masa dari 270jt manusia Indonesia ga bisa dapat 30 orang yg berbakat baik sepak bola. Pengelolaan yg mesti ditata kembali cari orang yg kompeten dan mau ngurus bola.
# 2. Link [https://x.com/Dwi85650673/status/1832776851896537412] : @pray_thekid Gk masalah karena dlm tubuh mereka mengalir darah indonesia Mereka membawa nama baik indonesia di Dunia sepak bola Klo pemain lokal bukan keturunan dan pengin tembus line up mereka harus berjuan dan menjadi yg terbaik.
# 3. Link [https://x.com/henzboriel/status/1832780330383925438] : @pray_thekid Udh Indonesia mah jadi penonton aja biar para keturunan yg main biar jdi motivasi . Wkwk Makin sulit jdi pemain TIMNAS. wkwk
# 4. Link [https://x.com/branjangankawat/status/1832782430190932208] : @RiaDjuwita @pray_thekid @Kutang2tang Lha itu buktinya semua pemain timnas orang naturalisasi semua . Mau alasan apa saja itu kan bukti kalau maunya ambil pemain yg sudah jadi mau gampangnya saja . Padahal sebenarnya pemain indonesia asli kan banyak yg punya potensi .
# 5. Link [https://x.com/Achonk_Saulsick/status/1832785646685167708] : @pray_thekid Seneng banget liat puncak kehancuran bola indonesia. Negara sebelah vietnam thailand udah sampai piramida kompetisi. Futsal thailand piala dunia timnas bola wanita vietnam piala dunia. Indo masih cari pemain keturunan untuk sepak bola. Negara indonesia yg maen orang belanda

# %% [markdown]
# ## Visualisasi (Analisis Sentimen)

# %%
# Membuat dataframe baru tanpa duplikasi berdasarkan teks untuk analisis sentimen
# Agar tidak dipengaruhi oleh adanya spam ataupun buzzer
df2 = df_final.drop_duplicates(subset=['teks_rapih'])
df2.shape
# Out:
# (2350, 18)

# %% [markdown]
# ### Pie chart sentimen

# %%
# Menghitung distribusi kategori
category_counts = df2['sentiment_label'].value_counts()

# Membuat pie chart
category_counts.plot.pie(autopct='%1.1f%%', colors=['lightgreen', 'skyblue', 'lightcoral'])

# Menambahkan judul
plt.title('Distribusi Kategori')

# Menampilkan chart
plt.ylabel('')  # Menghilangkan label y agar lebih rapi
plt.show()

# %% [markdown]
# Interpretasi:
#
# - Positif (34.3%)
# 1. Keturunan Indonesia memiliki hak untuk membela Timnas
# 2. Proses naturalisasi diakui secara aturan
# 3. Naturalisasi menambah kualitas Timnas
#
# - Negatif (14.4%)
# 1. Kegagalan dalam pembinaan pemain lokal
# 2. Ketergantungan pada pemain asing
# 3. Ketidakseimbangan antara pemain lokal dan pemain naturalisasi

# %% [markdown]
# ### Word Cloud

# %%
# Mengolah kembali stopword, karena terdapat kata-kata baru yang mengganggu Word Cloud
# Hal ini di karenakan kata-kata tersebut muncul di semua kategori (di permasalahan sentimen)
# stopword khusus
stopword_nat = {'timnas indonesia','main timnas','indonesia','main naturalisasi','naturalisasi','sepak bola',
                'main','main turun','timnas','sepak','bola','sih','yg','u','iya','orang','nya','turun','keturunan',
                'lokal','negara','darah','bangga','liga','maju','warga','pakai','tim','belanda'}

# %%
# Fungsi Pembersih stopword
def clean_text(text, stopwords):
    # Mengubah teks menjadi huruf kecil
    text = text.lower()

    # Tokenisasi menggunakan TextBlob
    tokens = TextBlob(text).words

    # Menghapus stopwords
    filtered_tokens = [token for token in tokens if token not in stopwords]

    # Menggabungkan kembali token menjadi teks
    return ' '.join(filtered_tokens)

# Membuat kolom baru tanpa stopword khusus
df2['stem_teksnew'] = df2['stem_teks'].apply(lambda x: clean_text(x, stopword_nat))
# Out:
# <ipython-input-39-4b36c4f0a3dd>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['stem_teksnew'] = df2['stem_teks'].apply(lambda x: clean_text(x, stopword_nat))

# %%
# Fungsi untuk memanggil baris yang mengandung beberapa keyword
def filter_teks_multi_kata(df2, kolom, kata_kunci):
    # Membuat filter untuk semua kata kunci
    mask = df2[kolom].str.contains(kata_kunci[0], case=False, na=False)
    for kata in kata_kunci[1:]:
        mask &= df2[kolom].str.contains(kata, case=False, na=False)
    return df2[mask]

# %% [markdown]
# #### WC sentimen positif

# %%
dfpos = df2[df2['sentiment']==3]

# %%
# Gabungkan kolom teks jika ada
text = " ".join(dfpos['stem_teksnew'])

# Generate dan tampilkan word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# Interpretasi:
#
# Beberapa kata yang paling digunakan adalah ‘bela’, ‘asing’, ‘bagus’, salah’, ‘beda’, dan sebagainya. Netizen berpendapat bahwa naturalisasi sah secara aturan dan pemain asing keturunan Indonesia berhak membela timnas. Hal ini juga dianggap baik dalam upaya meningkatkan kualitas timnas.

# %%
# melihat isi tweet berdasarkan beberapa kata kunci yang besar
dfposwhat = filter_teks_multi_kata(dfpos, 'stem_teksnew', ['bela','asing'])
listpos = list(dfposwhat['full_text'])
listurlpos = list(dfposwhat['tweet_url'])
for i in range(len(listpos)):
  print(f"{i+1}. Link [{listurlpos[i]}] : {listpos[i]}")
# Out:
# 1. Link [https://x.com/rndmaulana/status/1834130219177050386] : @Indostransfer Maluu? Mereka semua pemain keturunan mereka ada darah indonesia mereka berhak membela negerinya sendiri. Agak sakit sih pas baca bagian bangsa asing padahal jelas orang tua/kakek nenek mereka orang indonesia. Tapi ya mau gmna semoga sepakbola diindonesia segera mulai dirapihkan
# 2. Link [https://x.com/AuliaZlatan/status/1834206645003714941] : @garistengah_id makanya di eropa ga jarang kita sering melihat pemain bola yg bersaudara tapi beda membela negara. itu semua karena ada faktor Darah keturunan/Naturalisasi. ga semata2 orang bule main di timnas dibilang naturalisasi siapa tau dari silsilah nya memang keturunan King INDONESIA.
# 3. Link [https://x.com/ahcinomanirbev/status/1834626049357009120] : Pan Pon Pan Pon noooh seluruh perhatian mah ke naturalisasi pemain asing timnas. Mungkin atlit PON juga harus cari yang mau dinaturalisasi buat bela Indonesia baru dah makannya rasa hotel bintang sepuluh.
# 4. Link [https://x.com/andikaardi48891/status/1834634146083488211] : @JakOnline Kalian sbuk ngurusin naturalisasi hey mereka ada darah indonesia nya bos. Knp kalian gk rbutin dlu c.gonzalwz greg no kolo yg gk ad darah indonesianya bela timnas pdhal jls2 cra licik club aga nambah kuota pemain asing. Cntoh lu nikah ama bule anak lu pgen bela timnas blh gk?
# 5. Link [https://x.com/meipri/status/1834817504494907592] : @pangeransiahaan secara teknis semua dilakuin kok sama Indonesia outputnya sama-sama pemain keturunan asing bela negara.
# 6. Link [https://x.com/Zahigkeit_/status/1835007294930895218] : ngomong² yang lagi rame sekarang kok pada anti banget dah sama naturalisasi padahal mereka ini masih ada kaitannya dengan indo. orang tua kakek nenek mereka ini ada yang asal dari indonesia. semisal lu nikah sama org asing masa anaknya gak boleh bela timnas wkwkkw wtf bro
# 7. Link [https://x.com/Aditya_Tetsu48/status/1835412859137986894] : @une_rijal @speakbola_id @kegblgnunfaedh Lagi pula yg di naturalisasi itu mereka punya darah Indonesia jadi mereka berhak bela timnas apalagi kualitas mereka bagus dan disiplin. Lu kalau punya anak hasil kawin sama bule dilarang main timnas marah kaga?
# 8. Link [https://x.com/franbekem88105/status/1835861299416424784] : @bachrum_achmadi Naturalisasi itu cm proses. Toh mereka yg skrg main jg sejak lahir ada hubungan nya sama indonesia.masak iya loe nikah sama bule terus anakmu mau bela timnas kagak boleh. Aneh kalii
# 9. Link [https://x.com/ki4524887396915/status/1836772694047744377] :  Naturalisasi vs Lokal: Apa bedanya? Pemain naturalisasi adalah mereka yang punya darah keturunan Indonesia meskipun lahir atau tumbuh besar di luar negeri. Dengan proses naturalisasi mereka mendapatkan kewarganegaraan Indonesia dan berhak membela Timnas. Walaupun 'asing'

# %%
# melihat isi tweet  berdasarkan beberapa kata kunci yang besar
dfposwhat2 = filter_teks_multi_kata(dfpos, 'stem_teksnew', ['salah','dukung'])
listpos2 = list(dfposwhat2['full_text'])
listurlpos2 = list(dfposwhat2['tweet_url'])
for i in range(len(listpos2)):
  print(f"{i+1}. Link [{listurlpos2[i]}] : {listpos2[i]}")
# Out:
# 1. Link [https://x.com/NATHANPROTECT/status/1833437298844918128] : Masih menyayangkan ada yg bilang &amp; mengkotak kotakkan naturalisasi &amp; lokal Apa yg salah?? Mereka WNI mereka punya dokumen sbg WNI mereka semua timnas Indonesia mereka sama dpt porsi yg sama Harusnya gk ada komen begitu lebih baik support as team as Indonesia
# 2. Link [https://x.com/jen75088/status/1834255544019755356] : kayak g habis pikir ada orang kayak gitugue bakal dukung pemanggilan pemain keturunan buat naturalisasi di Indonesia dan pembinaan pemain salah satunya bisa melalui main abroad dan peringkat fifa kita harus naik buat itu
# 3. Link [https://x.com/AS76509428/status/1834689120863764511] : @pangeransiahaan Selama bisa bikin nama indonesia ada di pildun ITU SEMUA SAH DAN NGGAK NYALAHIN ATURAN mau lokal mau pemain keturunan persetan dg itu.. Tinggal diem dan dukung ngga bacot a b c ..
# 4. Link [https://x.com/IndonesiaF56951/status/1835461200840368171] : @FahmiAgustian Pro &amp; kontra naturalisasi pasti ada namun tidak ada salahnya mendukung seluruh pemain timnas selagi mereka berjuang di level piala dunia selagi timnas berjuang pembinaan usia muda perbaikan kualitas liga wasit stadion &amp; pemberantasan mafia bola tetap harus diutamakan.

# %% [markdown]
# #### WC Sentimen Negatif

# %%
dfneg = df2[df2['sentiment']==1]

# %%
# Gabungkan kolom teks jika ada
text = " ".join(dfneg['stem_teksnew'])

# Generate dan tampilkan word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# Interpretasi:
#
# Beberapa kata yang paling digunakan adalah ‘asli’, ‘bina’, ‘banyak’, kritik’, ‘bodoh’, dan sebagainya. Netizen merasa tidak puas terhadap pengembangan pemain lokal (asli Indonesia) dan cemas terhadap identitas timnas yang bergantung pada pemain asing. Netizen juga menyerukan pembinaan yang lebih baik untuk penguatan identitas nasional timnas Indonesia.

# %%
# melihat isi tweet berdasarkan beberapa kata kunci yang besar
dfnegwhat = filter_teks_multi_kata(dfneg, 'stem_teksnew', ['bina','banyak'])
listneg = list(dfnegwhat['full_text'])
listurlneg = list(dfnegwhat['tweet_url'])
for i in range(len(listneg)):
  print(f"{i+1}. Link [{listurlneg[i]}] : {listneg[i]}")
# Out:
# 1. Link [https://x.com/fredyjuniartz/status/1833720013582196792] : @dribble9 Timnas sekarang perbanyak naturalisasi liga sekarang pake 8 pemain asing kompetisi yo cuman 1 piala Indonesia gak ada pembinaan? Yo mampus bang
# 2. Link [https://x.com/Sh4d4mhu53n/status/1835150344852324457] : @03__nakula @erickthohir Emang udh paling bener yg ngisi Timnas lebih dibanyakin pemain keturunan aja cuma pemain yg full indo yg punya kualitas terbaik yg ngisi timnas Pemain Liga Indonesia yg msh punya jiwa beladiri sok jagoan dilapangan dibuang aja jauh2.. Pembinaan Memble. Pengurus Goblok.
# 3. Link [https://x.com/ikd2009/status/1835274142708597094] : @kegblgnunfaedh Setuju...kalaupun timnas bola indonesia levelnya meningkat karena banyaknya pemain naturalisasi itu bukan sebuah keberhasilan menurut sy tapi kegagalan melakukan pembinaan
# 4. Link [https://x.com/apasajalah_11/status/1836218678255427914] : @GanesWilly78549 @Bali_Football Soal pengamat dan pihak yang sok kritisi pemain keturunan mereka sudah bertahun-tahun ada di sepakbola Indonesia dan ada yang pernah di federasi tapi apa yang mereka lakukan? Pembinaan? Bikin liga bagus? Ningkatin performa wasit? Perbanyak pelatih bagus?

# %%
# melihat isi tweet berdasarkan beberapa kata kunci yang besar
dfnegwhat2 = filter_teks_multi_kata(dfneg, 'stem_teksnew', ['asli','isi'])
listneg2 = list(dfnegwhat2['full_text'])
listurlneg2 = list(dfnegwhat2['tweet_url'])
for i in range(len(listneg2)):
  print(f"{i+1}. Link [{listurlneg2[i]}] : {listneg2[i]}")
# Out:
# 1. Link [https://x.com/GabunganL927/status/1834851580941943240] : @msaid_didu @PeterGontha sangat sependapat dgn pak peter. trus apakah kalian bangga dgn timnas (naturalisasi) sekarang? Terusterang aku Tidak...! Sejelek-jelek timnas asli indonesia aku lebih suka... Hanyasaja perlu profesional dlm rekrutmen dan latihan fisik.
# 2. Link [https://x.com/jeff23greenwood/status/1835318191347884258] : @speakbola_id @kegblgnunfaedh Emg ga ada yg larang dan negara2 lain pun melakukan. Dia kan bicara soal idealisme bagaimana layaknya timnas itu isinya ya org2 nasional Indonesia asli (selayaknya begitu) ya kalo timnas isinya naturalisasi semua ya ini jd kek joki doang tapi resmi
# 3. Link [https://x.com/PickNavaHOi/status/1840355491442315617] : @Cemen11388788 ya' maklum isinya 90% pemain ASLI Indonesia + bule (keturunan kompeni) cuma ada 1-2 yg main tapi klo dh sering main bareng bisa sesolid Timnas yg Juara Piala AFF tahun kemaren yg isinya SAMA ; 90% pemain lokal + bule (keturunan) cuma 1-2 klo menang sensasi-nya Beda Lebih Kerasa

# %%
# melihat isi tweet berdasarkan beberapa kata kunci yang besar
dfnegwhat3 = filter_teks_multi_kata(dfneg, 'stem_teksnew', ['rocky','dapat'])
listneg3 = list(dfnegwhat3['full_text'])
listurlneg3 = list(dfnegwhat3['tweet_url'])
for i in range(len(listneg3)):
  print(f"{i+1}. Link [{listurlneg3[i]}] : {listneg3[i]}")
# Out:
# 1. Link [https://x.com/RusminPrima/status/1835020686802452604] : @sukanyepak_bola Kali ini saya sependapat dengan bung Rocky dan Peter Gontha..... Jumlah Pemain Naturalisasi yg wajar di starting line-up timnas pada saat bertanding menurut saya paling maksimal 3 pemain naturalisasi bukan sampai 9 pemain.. Jadi timnas Indonesia tapi rasa asing .. Just Opinion..
# 2. Link [https://x.com/Erenyeager0510/status/1835274364469600522] : @kegblgnunfaedh sependapat dengan pendapat dari pak RG. Adanya naturalisasi di dalam kubu timnas indonesia adalah bukti ketidakmampuan SDM lokal dalam kancah sepak bola.

# %% [markdown]
# ### Tren Sentimen (September)

# %%
# Tentukan event_date
event_date1 = pd.to_datetime('2024-09-05') # Tanggal Laga Pertama Indonesia di Kualifikasi Piala Dunia Putaran ketiga (Indonesia vs Arab)
event_date = pd.to_datetime('2024-09-10') # Tanggal Laga Kedua Indonesia di Kualifikasi Piala Dunia Putaran ketiga (Indonesia vs Australia)

# Fungsi untuk menentukan waktu (before, during, after)
def classify_time(date, event_date,event_date1):
    if date < event_date1: # Sebelum laga pertama
        return 'before'
    elif date.date() > event_date.date(): # Setelah laga kedua
        return 'after'
    else: # dalam interval antara laga pertama dan kedua
        return 'during'

# Terapkan fungsi pada kolom 'Tanggal' dan buat kolom baru 'Waktu'
df2['Waktu'] = df2['created_at'].apply(lambda x: classify_time(x, event_date, event_date1))
# Out:
# <ipython-input-50-ddb8269bc0e4>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Waktu'] = df2['created_at'].apply(lambda x: classify_time(x, event_date, event_date1))

# %%
# Menghitung jumlah pengguna unik di setiap kombinasi Waktu dan Sentimen
pivot_data = df2.groupby(['Waktu', 'sentiment_label'])['username'].nunique().unstack(fill_value=0)
desired_order = ['before', 'during', 'after']
pivot_data = pivot_data.reindex(desired_order)

# Membuat line plot dengan jumlah pengguna unik
pivot_data.plot(kind='line', marker='o', figsize=(8, 6))

# Menambahkan judul dan label
plt.title('Perbandingan Sentimen Sebelum, Selama, dan Setelah (Jumlah Pengguna Unik)')
plt.xlabel('Waktu')
plt.ylabel('Jumlah Pengguna Unik')
plt.xticks(rotation=0)
plt.legend(title='Sentimen', loc='upper left')
plt.grid(True)
plt.show()

# %% [markdown]
# Interpretasi:
#
# - “Sebelum” (before): Jumlah pengguna dengan sentimen negatif, netral, dan positif relatif rendah. Ini menunjukkan bahwa sebelum pertandingan dimulai, tingkat aktivitas dan opini publik masih belum tinggi.
#
# - “Selama” (during): Sentimen positif meningkat signifikan, diikuti oleh kenaikan sentimen netral dan sedikit peningkatan sentimen negatif. Peningkatan ini mencerminkan respons positif publik terhadap performa timnas selama pertandingan Indonesia vs Arab dan Indonesia vs Australia.
#
# - “Setelah” (after): Peningkatan terbesar terjadi pada setiap sentimen. Hal ini menunjukkan bahwa kedua pertandingan telah menghasilkan peningkatan aktivitas dan diskusi yang signifikan di platform Twitter (X) ini, menunjukkan bahwa dampak signifikan dari kedua pertandingan.

# %% [markdown]
# # Kesimpulan

# %% [markdown]
# - Isu utama yang dibahas mencakup kegagalan pembinaan pemain lokal, ketergantungan pada pemain asing, dan dampaknya terhadap identitas tim nasional. Di sisi lain, dukungan terhadap kebijakan ini berfokus pada peningkatan kualitas permainan dan hak pemain keturunan untuk membela Timnas Indonesia.
# - Sentimen publik didominasi pandangan positif (34,3%), menyoroti manfaat naturalisasi untuk meningkatkan performa tim. Sebagian memiliki sentimen negatif (14,4%), dengan kritik utama pada lemahnya pembinaan pemain lokal. Sentimen netral juga cukup besar, mencerminkan opini berimbang.
# - Pola percakapan menunjukkan lonjakan diskusi signifikan pada 12-13 September, dipicu statement yang dikeluarkan oleh peter gontha menunjukkan ketidaksetujuan terhadap kebijakan PSSI terkait naturalisasi Timnas dan antusiasme publik dalam kualifikasi Piala Dunia.
# - Respons netizen menunjukkan pandangan yang beragam. Pendukung berpendapat bahwa kebijakan ini sah dan memperkuat Timnas, sementara kritik terutama datang dari kekhawatiran ketergantungan pada pemain asing dan seruan untuk memperbaiki pembinaan pemain lokal.

# %% [markdown]
# # Saran

# %% [markdown]
# - Pembinaan Pemain Lokal : PSSI perlu meningkatkan program pembinaan usia muda dengan menyediakan fasilitas, pelatihan, dan kompetisi yang berkualitas. Pemerintah dapat mendukung melalui pendanaan dan kebijakan untuk memastikan pemain lokal memiliki peluang yang sama untuk berkembang seperti pemain asing.
# - Keseimbangan Kebijakan Naturaliasi : Kebijakan naturalisasi sebaiknya tidak menjadi solusi utama, melainkan pelengkap strategi jangka panjang. PSSI harus tetap memprioritaskan pembinaan pemain lokal sebagai tulang punggung tim nasional sambil menggunakan pemain naturalisasi untuk memperkuat posisi tertentu yang masih kekurangan talenta.
# - Peningkatan Transparansi Kebijakan Naturalisasi: Transparansi dalam proses naturalisasi, termasuk alasan memilih pemain tertentu dan dampaknya terhadap tim, akan membantu meredam kritik publik. PSSI dapat mengkomunikasikan tujuan strategis serta kebijakan ini kepada masyarakat dengan lebih jelas. Dan membuat masyarakat lebih terdukasi tentang alasan naturalisasi dan dampaknya dapat memperkuat dukungan terhadap kebijakan ini.
# - Pemanfaatan Pemain Naturalisasi sebagai Mentor Pemain Muda : Pelatih dapat mengoptimalkan kehadiran pemain naturalisasi dengan mendorong mereka menjadi mentor bagi pemain muda lokal, sehingga pengalaman dan keterampilan mereka dapat ditransfer kepada generasi berikutnya.
# - Kolaborasi Pemerintah dan PSSI : Pemerintah dapat mendukung pembinaan pemain lokal dengan meningkatkan anggaran pengembangan olahraga, memperbaiki infrastruktur sepak bola, dan memastikan pemerataan akses pelatihan di seluruh daerah.
